# %% [markdown]
# <a href="https://colab.research.google.com/github/maryamathar/2022S1/blob/main/A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2 - Find complex answers to medical questions
#
# **Submission deadline: Friday 22 April, 5pm.**
#
# Late submissions **will not be accepted** without an approved [Special Consideration](http://from.mq.edu.au/MT0X0E0FUrrU200rm0JB0U0) request.  Assessments submitted after the due date will receive a mark of **zero**.
#
# **Assessment marks: 20 marks (20% of the total unit assessment)**
#
# In this assignment we will work on a task of "query-focused summarisation" on medical questions where the goal is, given a medical question and a list of sentences extracted from relevant medical publications, to determine which of these sentences from the list can be used as part of the answer to the question.
#
# We will use data that has been derived from the **BioASQ challenge** (http://www.bioasq.org/), after some data manipulation to make it easier to process for this assignment. The BioASQ challenge organises several "shared tasks", including a task on biomedical semantic question answering which we are using here. The data are in the file `bioasq10_labelled.csv`, which is part of the zip file provided. Each row of the file has a question, a sentence text, and a label that indicates whether the sentence text is part of the answer to the question (1) or not (0).
#
# The following code uses pandas to store the file `bioasq10_labelled.csv` in a data frame and show the first rows of data. For this code to run, first you need to unzip the file `data.zip`:

# %%
# !unzip data.zip
# Out:
# unzip:  cannot find or open data.zip, data.zip.zip or data.zip.ZIP.

# %%
import pandas as pd
dataset = pd.read_csv("bioasq10b_labelled.csv")
dataset.head()
# Out:
#    qid  sentid                                           question  \
# 0    0       0  Is Hirschsprung disease a mendelian or a multi...
# 1    0       1  Is Hirschsprung disease a mendelian or a multi...
# 2    0       2  Is Hirschsprung disease a mendelian or a multi...
# 3    0       3  Is Hirschsprung disease a mendelian or a multi...
# 4    0       4  Is Hirschsprung disease a mendelian or a multi...
#
#                                        sentence text  label
# 0  Hirschsprung disease (HSCR) is a multifactoria...      0
# 1  In this study, we review the identification of...      1
# 2  The majority of the identified genes are relat...      1
# 3  The non-Mendelian inheritance of sporadic non-...      1
# 4                  Coding sequence mutations in e.g.      0

# %%
dataset.qid.size
# Out:
# 64112

# %% [markdown]
# The columns of the CSV file are:
#
# * `qid`: an ID for a question. Several rows may have the same question ID, as we can see above.
# * `sentid`: an ID for a sentence.
# * `question`: The text of the question. In the above example, the first rows all have the same question: "Is Hirschsprung disease a mendelian or a multifactorial disorder?"
# * `sentence text`: The text of the sentence.
# * `label`: 1 if the sentence is a part of the answer, 0 if the sentence is not part of the answer.

# %% [markdown]
# # Task 1 (5 marks): Data preparation
#
# Partition the data into the training, dev_test, and test sets using the proportions 6:2:2. That is, 60% of the questions must be in the training set, 20% must be in the dev_test set, and the remaining 20% in the test set. Make sure that you partition based on the questions, not on the rows. With this we mean that all the sentences related to a question must be in one file only. In other words, there must not be sentences from the same question in, say, the training and the test data.
#
# Also, make sure that you implement a random partition.
#
# Save the partitions as the files `training.csv`, `dev_test.csv`, and `test.csv`, so that they can be used by other people.
#
# The breakdown of marks is as follows:
#
# * **1 mark** if your explanation answers the following question correctly: Why do we want to split the partition on the questions, and not on the rows?
# * **1 mark** if the code partitions the data on the questions randomly and according to the split 6:2:2.
# * **1 mark** if your code generates partitions that have similar balance of labels and you demonstrate that they are similar.
# * **1 mark** if the partitions are saved as the CSV files `training.csv`, `dev_test.csv`, and `test.csv`.
# * **1 mark** for good coding and documentation in this task.

# %%
import random
random.seed(1234)
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
questions = list(set(dataset['question']))
print(len(questions))
# Out:
# 4234

# %%
random.shuffle(questions)

# %%
threshold1 = int(len(questions)*.6)
threshold2 = int(len(questions)*.8)
q_train = questions[:threshold1]
q_devtest = questions[threshold1:threshold2]
q_test = questions[threshold2:]

# %%
training_set = []
for d in q_train:
    document_data = dataset[dataset['question'] == d]
    training_set += list(document_data.itertuples(index=False, name=None))
training_set
# Out:
# [(2651,
#   0,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'n this work, we performed a computational analysis of the human mitochondrial genome using the "Pattern Finder" G-quadruplex (G4) predictor algorithm to assess whether G4-forming sequences reside in close proximity (within 20 base pairs) to known mitochondrial DNA deletion breakpoints.',
#   1),
#  (2651,
#   1,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'Circular dichroism and UV spectral analysis demonstrated that mitochondrial G-rich sequences near deletion breakpoints prevalent in human disease form G-quadruplex DNA structures.',
#   1),
#  (2651,
#   2,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'Direct repeat sequences are not required at the breakpoints of age-associated mitochondrial DNA deletions in rhesus monkeys.',
#   1),
#  (2651,
#   3,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'Most of the analyzed deletion breakpoints showed nucleotide repeats flanking the deletions.',
#   1),
#  (2651,
#   4,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'Currently, the multiple types of GQ sequences and their association with human mtDNA stability are unknown.<br><b>RESULTS</b>: Here, we show an association between human mtDNA deletion breakpoint locations (sites where DNA ends rejoin after deletion of a section) and sequences with G-quadruplex forming potential (QFP), and establish the ability of selected sequences to form GQ in vitro.',
#   0),
#  (2651,
#   5,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'A biochemical analysis of purified recombinant human Twinkle protein (gene product of c10orf2) showed that the mitochondrial replicative helicase inefficiently unwinds well characterized intermolecular and intramolecular G-quadruplex DNA substrates, as well as a unimolecular G4 substrate derived from a mitochondrial sequence that nests a deletion breakpoint described in human renal cell carcinoma.',
#   0),
#  (2651,
#   6,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'DNA sequences proximal to human mitochondrial DNA deletion breakpoints prevalent in human disease form G-quadruplexes, a class of DNA structures inefficiently unwound by the mitochondrial replicative Twinkle helicase.',
#   1),
#  (2651,
#   7,
#   'Where do mitochondrial DNA deletion breakpoints tend to occur?',
#   'Association of G-quadruplex forming sequences with human mtDNA deletion breakpoints.',
#   0),
#  (1524,
#   0,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'The initial treatment for SUI that persists after 12 months consists of conservative measures such as pelvic floor muscle exercises and behavioral therapy.',
#   0),
#  (1524,
#   1,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'Properly selected and informed patients can also be treated efficiently with minimally invasive procedures such as the implantation of a male suburethral sling, although the experience with such devices is not extensive.',
#   1),
#  (1524,
#   2,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'However, the implantation of artificial urinary sphincter is the gold standard therapy.',
#   1),
#  (1524,
#   3,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'treatments such as periurethral injection of bulking agents, artificial urinary sphincter (AUS) implantation, and sub-urethral sling positioning.',
#   1),
#  (1524,
#   4,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'The artificial urethral sphincter has represented, until today, the gold standard but, in the recent years, sling systems have been investigated as minimally invasive alternative options.',
#   1),
#  (1524,
#   5,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'Today, three different sling procedures are commonly performed: bone-anchored, readjustable, and trans-obturator slings systems.',
#   0),
#  (1524,
#   6,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'The bone anchored suburethral synthetic sling is a simple and attractive procedure that can produce immediate good results with low morbidity, especially when strictly selected patients are treated.',
#   0),
#  (1524,
#   7,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'BAUS implantation is a safe, effective, minimally invasive option for iatrogenic male incontinence due to ISD.',
#   1),
#  (1524,
#   8,
#   'What is the gold standard treatment for Iatrogenic male incontinence?',
#   'It compares favourably with AUS.',
#   0),
#  (45,
#   0,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'The meta-analyses yielded significantly increased risks for all CNS tumors, glioma and meningioma in users of estrogen-only [1.35 (1.22-1.49), 1.23 (1.06-1.42) and 1.31 (1.20-1.43), respectively] but not estrogen-progestin HT [1.09 (0.99-1.19), 0.92 (0.78-1.08) and 1.05 (0.95-1.16), respectively]; these differences were statistically significant (p<0.005 for each tumor type).',
#   0),
#  (45,
#   1,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'There was no significant difference between glioma and meningioma risk in users of estrogen-only HT.',
#   1),
#  (45,
#   2,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'The totality of the available evidence suggests an increased risk of all CNS tumors (and of glioma and meningioma separately) in users of estrogen-only HT.',
#   0),
#  (45,
#   3,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Among premenopausal women, current use of oral contraceptives was associated with an increased risk of meningiomas (OR 1.8, 95% CI 1.1-2.9), while current use of hormone replacement therapy among postmenopausal women was not associated with a significant elevation in risk (OR 1.1, 95% CI 0.74-1.67).',
#   0),
#  (45,
#   4,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'The relationship between current use of exogenous hormones and meningioma remains unclear, limited by the small numbers of patients currently on oral hormone medications and a lack of hormone receptor data for meningioma tumors.',
#   0),
#  (45,
#   5,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Ever use of estradiol-only therapy was associated with an increased risk of meningioma (standardized incidence ratio = 1.29, 95% confidence interval: 1.15, 1.44).',
#   0),
#  (45,
#   6,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Among women who had been using estradiol-only therapy for at least 3 years, the incidence of meningioma was 1.40-fold higher (95% confidence interval: 1.18, 1.64; P<0.001) than in the background population.',
#   0),
#  (45,
#   7,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Estradiol-only therapy was accompanied with a slightly increased risk of meningioma.',
#   0),
#  (45,
#   8,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Results from several prospective, large-scale studies indicate that postmenopausal hormone therapy may increase the risk for diagnosing meningioma by 30-80%, but there is no effect in regard to glioma.',
#   0),
#  (45,
#   9,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'A retrospective study including more than 350,000 women, about 1400 of whom had developed meningioma, showed that the risk of meningioma was about twice as high in users of postmenopausal hormone replacement therapy as in non-users.',
#   0),
#  (45,
#   10,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Compared with never users of HRT, the relative risks (RRs) for all incident CNS tumours, gliomas, meningiomas and acoustic neuromas in current users of HRT were 1.20 (95% CI: 1.05-1.36), 1.09 (95% CI: 0.89-1.32), 1.34 (95% CI: 1.03-1.75) and 1.58 (95% CI: 1.02-2.45), respectively, and there was no significant difference in the relative risks by tumour type (heterogeneity p = 0.2).',
#   0),
#  (45,
#   11,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'BACKGROUND: Previous studies on association of exogenous female sex hormones and risk for meningioma have yielded conflicting results.',
#   0),
#  (45,
#   12,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'RESULTS: Postmenopausal hormonal treatment, use of contraceptives, or fertility treatment did not influence the risk of meningioma.',
#   0),
#  (45,
#   13,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'CONCLUSIONS: Overall, we found little indication that reproductive factors or use of exogenous sex hormones affect meningioma risk.',
#   0),
#  (45,
#   14,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Although not definitive, available data suggest an association between the use of hormone replacement therapy and increased meningioma risk.',
#   1),
#  (45,
#   15,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'BACKGROUND: The role of exogenous hormone exposures in the development of meningioma is unclear, but these exposures have been proposed as one hypothesis to explain the over-abundance of such tumors in women.',
#   0),
#  (45,
#   16,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'RESULTS: Although risk of meningioma appeared modestly elevated in past OC users (OR = 1.5, 95% CI 0.8 - 2.7), and in current users (OR = 2.5, 95% CI 0.5 - 12.6), the confidence intervals were wide.',
#   0),
#  (45,
#   17,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Likewise, risk of meningioma was only weakly associated with past use of HRT (OR = 0.7, 95% CI 0.4 - 1.3), and not at all with current use of HRT (OR = 1.0, 95% CI 0.5 - 2.2).',
#   0),
#  (45,
#   18,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   ' Overall, in post menopausal women, HRT use appeared to confer a non-significant protective effect, and was not associated with low or high PR expressing meningiomas.CONCLUSION: This study found little evidence of associations between meningioma and exogenous hormone exposures in women but did suggest that some hormonal exposures may influence tumor biology in those women who develop meningioma.',
#   0),
#  (45,
#   19,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'The increased odds ratios with African Americans was retained in post-menopausal women, while the protective odds ratios for pregnancy, smoking and oral contraceptives (OCs) became stronger in pre-menopausal women.',
#   0),
#  (45,
#   20,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'The pattern by duration and timing of use does not suggest an etiologic role for OCs or hormone replacement therapy.',
#   0),
#  (45,
#   21,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'The use of hormone replacement therapy in symptomatic postmenopausal women either with previously treated disease or with dormant tumors is discussed, but remains controversial.',
#   0),
#  (45,
#   22,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Although not definitive, available data suggest an association between the use of hormone replacement therapy and increased meningioma risk.',
#   1),
#  (45,
#   23,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'OC use was associated with increased risk of a meningioma expressing less rather than more PR (OR = 3.2, 95% CI 1.3 - 8.0).',
#   0),
#  (45,
#   24,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'In further analysis by hormone receptor status, there was some indication for an increased risk of progesterone receptor-positive meningiomas associated with oral contraceptive use (OR 1.39, 95% confidence interval 0.92-2.10) and other hormonal contraception (OR 1.50, 95% CI 0.95-2.36).',
#   0),
#  (45,
#   25,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Several studies indicate that use of hormone replacement therapy (HRT) is associated with an increased risk of intracranial meningioma, while associations between HRT use and risk of other brain tumors have been less explored.',
#   0),
#  (45,
#   26,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'available data suggest an association between the use of hormone replacement therapy and increased meningioma risk.',
#   1),
#  (45,
#   27,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'A significant positive association existed between meningioma risk and increased body mass index (p &lt; 0.01) while a significant negative association existed between meningioma risk and current smoking (p &lt; 0.01).',
#   0),
#  (45,
#   28,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Among premenopausal women, current use of oral contraceptives was associated with an increased risk of meningiomas (OR 1.8, 95% CI 1.1-2.9), while current use of hormone replacement therapy among postmenopausal women was not associated with a significant elevation in risk (OR 1.1, 95% CI 0.74-1.67).',
#   0),
#  (45,
#   29,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'A higher risk of meningioma was observed among postmenopausal women who were current users of hormone replacement therapy (HR,',
#   0),
#  (45,
#   30,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Among premenopausal women, current use of oral contraceptives was associated with an increased risk of meningiomas (OR 1.8, 95% CI 1.1-2.9), while current use of hormone replacement therapy among postmenopausal women was not associated with a significant elevation in risk (OR 1.1, 95% CI 0.74-1.67).',
#   0),
#  (45,
#   31,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'There was no association between use of fertility medications and meningioma risk.',
#   0),
#  (45,
#   32,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Although not definitive, available data suggest an association between the use of hormone replacement therapy and increased meningioma risk.',
#   1),
#  (45,
#   33,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'A higher risk of meningioma was observed among postmenopausal women who were current users of hormone replacement therapy (HR, 1.79; 95% CI, 1.18-2.71) compared with never users.',
#   0),
#  (45,
#   34,
#   'What is the association of estrogen replacement therapy and intracranial meningioma risk?',
#   'Among premenopausal women, current use of oral contraceptives was associated with an increased risk of meningiomas (OR 1.8, 95% CI 1.1-2.9), while current use of hormone replacement therapy among postmenopausal women was not associated with a significant elevation in risk (OR 1.1, 95% CI 0.74-1.67).',
#   0),
#  (3225,
#   0,
#   'What is a SMR based BCI?',
#   ' sensorimotor rhythm-based brain-computer interfaces (SMR-BCI)',
#   1),
#  (3225,
#   1,
#   'What is a SMR based BCI?',
#   'Here, we studied the immediate and therapeutic effects of BCI-based training to control pre-movement sensorimotor rhythm (SMR) amplitude on robot-assisted finger extension in people with stroke.',
#   0),
#  (3225,
#   2,
#   'What is a SMR based BCI?',
#   ' Especially for BCIs based on the modulation of the Sensorimotor Rhythm (SMR)',
#   1),
#  (3225,
#   3,
#   'What is a SMR based BCI?',
#   'Brain Computer Interface (BCI) and neurofeedback studies have investigated the impact of sensorimotor rhythm (SMR)',
#   1),
#  (3225,
#   4,
#   'What is a SMR based BCI?',
#   'Modulation of sensorimotor rhythms (SMR) was suggested as a control signal for brain-computer interfaces (BCI).',
#   0),
#  (3225,
#   5,
#   'What is a SMR based BCI?',
#   'Sensorimotor rhythm (SMR) based Brain-Computer Interfaces (BCI) typically require lengthy user training.',
#   1),
#  (3225,
#   6,
#   'What is a SMR based BCI?',
#   'All brain-computer interface (BCI) groups that have published results of studies involving a large number of users performing BCI control based on the voluntary modulation of sensorimotor rhythms (SMR) report that BCI control could not be achieved by a non-negligible number of subjects (estimated 20% to 25%).',
#   1),
#  (3225,
#   7,
#   'What is a SMR based BCI?',
#   'OBJECTIVE\nConnect-Four, a new sensorimotor rhythm (SMR) based brain-computer interface (BCI) gaming application, was evaluated by four severely motor restricted end-users; two were in the locked-in state and had unreliable eye-movement.',
#   0),
#  (3225,
#   8,
#   'What is a SMR based BCI?',
#   'OBJECTIVE\nIt is well known that to acquire sensorimotor (SMR)-based brain-computer interface (BCI) control requires a training period before users can achieve their best possible performances.',
#   0),
#  (2563,
#   0,
#   'What is host induced gene silencing?',
#   'Host-induced gene silencing (HIGS) is a transgenic technology used to silence fungal genes in planta during attempted infection and thereby reduces disease levels.',
#   1),
#  (2563,
#   1,
#   'What is host induced gene silencing?',
#   "HIGS relies on the host plant's ability to produce mobile small interfering RNA molecules, generated from long double-stranded RNA, which are complementary to targeted fungal genes.",
#   1),
#  (2563,
#   2,
#   'What is host induced gene silencing?',
#   'These molecules are transferred from the plant to invading fungi via an uncharacterised mechanism, to cause gene silencing.',
#   1),
#  (2563,
#   3,
#   'What is host induced gene silencing?',
#   'We then discuss the developments and implications of combining HIGS with other methods of disease control.',
#   1),
#  (4184,
#   0,
#   'Are interferons defensive proteins?',
#   'In response to viral infections, various pattern recognition receptors (PRRs) are activated for the production of type I interferon (IFN I).',
#   1),
#  (4184,
#   1,
#   'Are interferons defensive proteins?',
#   ' activating interferon (IFN) production and positively regulating antiviral response in mammals.',
#   1),
#  (4184,
#   2,
#   'Are interferons defensive proteins?',
#   'The innate immune system, in particular the type I interferon (IFN) response, is a powerful defence against virus infections.',
#   1),
#  (4184,
#   3,
#   'Are interferons defensive proteins?',
#   'The interferon-induced GTP-binding protein Mx is responsible for a specific antiviral state against a broad spectrum of viral infections that are induced by type-I interferons (IFN α/β) in different vertebrates',
#   1),
#  (1382,
#   0,
#   'Describe the usefulness of Macrostomum lignano in ion channel and stem cell research',
#   'Bioelectrical signals generated by ion channels play crucial roles in many cellular processes in both excitable and nonexcitable cells.',
#   1),
#  (1382,
#   1,
#   'Describe the usefulness of Macrostomum lignano in ion channel and stem cell research',
#   'Some ion channels are directly implemented in chemical signaling pathways, the others are involved in regulation of cytoplasmic or vesicular ion concentrations, pH, cell volume, and membrane potentials.',
#   1),
#  (1382,
#   2,
#   'Describe the usefulness of Macrostomum lignano in ion channel and stem cell research',
#   'Together with ion transporters and gap junction complexes, ion channels form steady-state voltage gradients across the cell membranes in nonexcitable cells.',
#   1),
#  (1382,
#   3,
#   'Describe the usefulness of Macrostomum lignano in ion channel and stem cell research',
#   'These membrane potentials are involved in regulation of such processes as migration guidance, cell proliferation, and body axis patterning during development and regeneration.',
#   1),
#  (1382,
#   4,
#   'Describe the usefulness of Macrostomum lignano in ion channel and stem cell research',
#   'While the importance of membrane potential in stem cell maintenance, proliferation, and differentiation is evident, the mechanisms of this bioelectric control of stem cell activity are still not well understood, and the role of specific ion channels in these processes remains unclear.',
#   1),
#  (1382,
#   5,
#   'Describe the usefulness of Macrostomum lignano in ion channel and stem cell research',
#   'Here we introduce the flatworm Macrostomum lignano as a versatile model organism for addressing these topics.',
#   0),
#  (1382,
#   6,
#   'Describe the usefulness of Macrostomum lignano in ion channel and stem cell research',
#   'We discuss biological and experimental properties of M. lignano, provide an overview of the recently developed experimental tools for this animal model, and demonstrate how manipulation of membrane potential influences regeneration in M. lignano.',
#   0),
#  (1309,
#   0,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'The histidine-rich Ca-binding protein (HRC) is a Ca-storage protein in cardiac sarcoplasmic reticulum.',
#   1),
#  (1309,
#   1,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'Recent transgenic studies revealed that this protein inhibits the maximal rates of sarcoplasmic reticulum Ca-transport, leading to cardiac dysfunction.',
#   1),
#  (1309,
#   2,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'In view of the role of sarcoplasmic reticulum Ca-cycling in myocardial ischemia/reperfusion injury, we designed this study to gain further insight into the role of HRC during ischemia/reperfusion.',
#   1),
#  (1309,
#   3,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'Our findings suggest that increased cardiac HRC expression protects against ischemia/reperfusion injury in the heart, resulting in improved recovery of function and reduced infarction.',
#   0),
#  (1309,
#   4,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'The histidine-rich calcium binding protein (HRC) Ser96Ala polymorphism was shown to correlate with ventricular arrhythmias and sudden death only in dilated cardiomyopathy patients',
#   1),
#  (1309,
#   5,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'The HRC(S96A) mutant exacerbated the inhibitory effects of HRC(WT) on the amplitude of Ca(2+) transients, prolongation of Ca(2+) decay time, and caffeine-induced sarcoplasmic reticulum Ca(2+) release.',
#   0),
#  (1309,
#   6,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'Consistent with these findings, HRC(S96A) reduced maximal sarcoplasmic reticulum calcium uptake rate to a higher extent than HRC(WT).',
#   0),
#  (1309,
#   7,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'Furthermore, the frequency of spontaneous Ca(2+) sparks, which was reduced by HRC(WT), was increased by mutant HRC(S96A) under resting conditions although there were no spontaneous Ca(2+) waves under stress conditions.',
#   0),
#  (1309,
#   8,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'However, expression of the HRC(S96A) genetic variant in cardiomyocytes from a rat model of postmyocardial infarction heart failure induced dramatic disturbances of rhythmic Ca(2+) transients.',
#   0),
#  (1309,
#   9,
#   'What is the role of the histidine rich calcium binding protein (HRC) in cardiomyopathy?',
#   'These findings indicate that the HRC Ser96Ala variant increases the propensity of arrhythmogenic Ca(2+) waves in the stressed failing heart, suggesting a link between this genetic variant and life-threatening ventricular arrhythmias in human carriers.',
#   1),
#  (1384,
#   0,
#   'Which drug is benserazide usually co-administered with?',
#   'The present study utilizes in vivo amperometry to investigate the impact from unilateral 6-hydroxydopamine lesions and l-DOPA (4 mg/kg, including benserazide 15 mg/kg) -induced dyskinetic behavior on striatal basal extracellular glutamate concentration and potassium-evoked glutamate release in urethane-anesthetized rats.',
#   0),
#  (1384,
#   1,
#   'Which drug is benserazide usually co-administered with?',
#   'Co-administration of L-Dopa with peripheral DDC inhibitors (carbidopa or benserazide) is the most effective symptomatic treatment for PD.',
#   1),
#  (1384,
#   2,
#   'Which drug is benserazide usually co-administered with?',
#   'In experiment 1, l-DOPA-primed rats were pre-treated with Vehicle (0.9% NaCl), various doses of the partial 5-HT(1A) agonist, buspirone (0.25, 1.0 or 2.5 mg/kg, ip) or buspirone (2.5 mg/kg, ip)+the 5-HT(1A) antagonist, WAY100635 (0.5 mg/kg, ip) 5 min prior to l-DOPA (12 mg/kg+15 mg/kg benserazide, ip).',
#   0),
#  (1384, 3, 'Which drug is benserazide usually co-administered with?', 'R', 0),
#  (1384,
#   4,
#   'Which drug is benserazide usually co-administered with?',
#   'L-DOPA induced hyperalgesia occurred after conversion to dopamine because co-administration of benserazide, a DOPA decarboxylase inhibitor, completely abolished the L-DOPA-induced hyperalgesia.',
#   1),
#  (1384,
#   5,
#   'Which drug is benserazide usually co-administered with?',
#   'First, animals were treated with levodopa (50 mg/kg with benserazide 12.5 mg/kg, twice daily), intraperitoneally (i.p.)',
#   0),
#  (1384,
#   6,
#   'Which drug is benserazide usually co-administered with?',
#   'for 22 days.',
#   0),
#  (1384,
#   7,
#   'Which drug is benserazide usually co-administered with?',
#   'Chronic L-DOPA-treated rats received the D1 receptor antagonist SCH23390 (0.01, 0.1, and 1.0 mg/kg; i.p.',
#   0),
#  (1384,
#   8,
#   'Which drug is benserazide usually co-administered with?',
#   '), the D2 receptor antagonist Eticlopride (0.01, 0.1, and 1.0 mg/kg; i.p.',
#   0),
#  (1384,
#   9,
#   'Which drug is benserazide usually co-administered with?',
#   '), a mixture of both antagonists (0.01, 0.1, 1.0 mg/kg each; i.p.',
#   0),
#  (1384,
#   10,
#   'Which drug is benserazide usually co-administered with?',
#   '), or vehicle 30 min prior to L-DOPA (6 mg/kg; i.p.',
#   0),
#  (1384,
#   11,
#   'Which drug is benserazide usually co-administered with?',
#   ')+Benserazide (15 mg/kg; i.p.',
#   0),
#  (1384,
#   12,
#   'Which drug is benserazide usually co-administered with?',
#   ').',
#   0),
#  (1384,
#   13,
#   'Which drug is benserazide usually co-administered with?',
#   'Nociceptive behaviors in mice after an intrathecal (i.t.)',
#   0),
#  (1384,
#   14,
#   'Which drug is benserazide usually co-administered with?',
#   'administration of substance P were evaluated.',
#   0),
#  (1384,
#   15,
#   'Which drug is benserazide usually co-administered with?',
#   'L-DOPA (i.t.)',
#   0),
#  (1384,
#   16,
#   'Which drug is benserazide usually co-administered with?',
#   'dose-dependently attenuated the substance P-induced nociceptive behaviors.',
#   0),
#  (1384,
#   17,
#   'Which drug is benserazide usually co-administered with?',
#   'Co-administration of benserazide (i.t.',
#   1),
#  (1384,
#   18,
#   'Which drug is benserazide usually co-administered with?',
#   '), a DOPA decarboxylase inhibitor, abolished the antinociceptive effect of L-DOPA.',
#   0),
#  (1384,
#   19,
#   'Which drug is benserazide usually co-administered with?',
#   'They were injected subcutaneously (s.c.) with L-DOPA methyl ester (125 mg per animal) plus benserazide (50 mg per animal; L-DOPA/benserazide) alone or in combination with (-)-OSU6162 (1.0, 3.0, 6.0 or 10 mg/kg, s.c.)',
#   0),
#  (1384,
#   20,
#   'Which drug is benserazide usually co-administered with?',
#   'They were injected subcutaneously (s.c.) with L-Dopa methyl ester (125 mg per animal) plus benserazide (50 mg per animal; L-Dopa/benserazide) alone or in combination with JL-18 (at the doses of 0.1, 0.3, or 0.9 mg/kg, s.c.).',
#   0),
#  (1384,
#   21,
#   'Which drug is benserazide usually co-administered with?',
#   'The administration of L-dopa (20 and 60 mg/kg p.o.)',
#   1),
#  (1384,
#   22,
#   'Which drug is benserazide usually co-administered with?',
#   '+ benserazide (15 mg/kg p.o.)',
#   0),
#  (1384,
#   23,
#   'Which drug is benserazide usually co-administered with?',
#   'resulted in dose-dependent increase of dialysate levels of L-dopa and 3-O-methyl-DOPA.',
#   0),
#  (1384,
#   24,
#   'Which drug is benserazide usually co-administered with?',
#   'Tolcapone (30 mg/kg p.o.',
#   0),
#  (1384,
#   25,
#   'Which drug is benserazide usually co-administered with?',
#   '), given as adjunct to both doses of L-dopa, markedly enhanced the elevation or extracellular L-dopa, while it completely prevented the formation of 3-O-methyl-DOPA.',
#   0),
#  (1384,
#   26,
#   'Which drug is benserazide usually co-administered with?',
#   'In another experiment, the administration of L-dopa + benserazide (30 + 15 mg/kg p.o.)',
#   1),
#  (1384,
#   27,
#   'Which drug is benserazide usually co-administered with?',
#   'resulted in increased extracellular levels of dopamine, DOPAC, HVA and 3-methoxytyramine.',
#   0),
#  (1384,
#   28,
#   'Which drug is benserazide usually co-administered with?',
#   'In healthy subjects and in patients with parkinsonism plasma ALAAD level fell after administration of L-dopa + benserazide, but returned to previous levels within 90 min.',
#   0),
#  (1384,
#   29,
#   'Which drug is benserazide usually co-administered with?',
#   'In a cross-sectional study blood was obtained, 2 h after dosing, from 104 patients with idiopathic parkinsonism, divided into four groups: no L-dopa treatment (group 1), L-dopa alone (group 2), L-dopa + benserazide (Madopar) (group 3) and L-dopa + carbidopa (Sinemet) (group 4).',
#   0),
#  (2591,
#   0,
#   'What is the proteoform?',
#   'proteoforms - splice variants, single amino acid substitutions (SAP variants), and post-translational modifications (PTM) of proteins',
#   1),
#  (2591,
#   1,
#   'What is the proteoform?',
#   'Although proteomics has rapidly developed in the past decade, researchers are still in the early stage of exploring the world of complex proteoforms, which are protein products with various primary structure alterations resulting from gene mutations, alternative splicing, post-translational modifications, and other biological processes',
#   1),
#  (2591,
#   2,
#   'What is the proteoform?',
#   'Protein species (aka proteoforms) function at their molecular level, and diverse structures and biological roles of every proteoform come from often co-occurring proteolysis, amino acid variation and post-translational modifications.',
#   1),
#  (2591,
#   3,
#   'What is the proteoform?',
#   'the identification of novel proteoforms is also made possible based on detection of novel translation initiation sites (cognate or near-cognate), novel transcript isoforms, sequence variation or novel (small) open reading frames in intergenic or un-translated genic regions by analyzing high-throughput sequencing data from RNAseq or ribosome profiling experiments.',
#   1),
#  (3270,
#   0,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'Belimumab: a BLyS-specific inhibitor for systemic lupus erythematosus',
#   1),
#  (3270,
#   1,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'To review the efficacy, safety, dosing, drug interactions, as well as economic and therapeutic considerations of belimumab, an investigational B-lymphocyte stimulator (BLyS) inhibitor.',
#   1),
#  (3270,
#   2,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'Belimumab, an anti-BAFF monoclonal antibody',
#   0),
#  (3270,
#   3,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'Here our crystal structure of the BAFF-belimumab Fab complex shows the precise epitope and the BAFF-neutralizing mechanism of belimumab, and demonstrates that the therapeutic activity of belimumab involves not only antagonizing the BAFF-receptor interaction, but also disrupting the formation of the more active BAFF 60-mer to favor the induction of the less active BAFF trimer through interaction with the flap region of BAFF',
#   0),
#  (3270,
#   4,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'In recent years, a member of the tumor necrosis factor (TNF) family, soluble human B Lymphocyte Stimulator protein (BLyS), also referred to as B-cell activating factor (BAFF) and TNFSF13B has been studied extensively.',
#   0),
#  (3270,
#   5,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'This protein is synthesized by myeloid cell lines, specifically interacts with B lymphocytes and increases their life-span',
#   0),
#  (3270,
#   6,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'Belimumab, a fully human monoclonal antibody against B lymphocyte stimulator (BLyS), a B-cell survival factor, was licensed in 2011 for the treatment of autoantibody-positive SLE',
#   1),
#  (3270,
#   7,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'Belimumab is a fully human monoclonal antibody directed against BAFF.',
#   1),
#  (3270,
#   8,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   ' Belimumab, a human monoclonal antibody specific for soluble BLyS, was ultimately approved by the United States Food and Drug Administration (FDA) in March 2011 for active autoantibody patients with systemic lupus erythematosus (SLE) despite standard therapy.',
#   1),
#  (3270,
#   9,
#   'Which is the target of belimumab in Systemic Lupus Erythematosus treatment?',
#   'Targeted therapy with belimumab, the monoclonal antibody against BLyS, has shown clinical benefit in two large-scale, multicenter phase III trials leading to US Food and Drug Administration approval for patients with serologically positive SLE who have active disease despite standard therapy',
#   0),
#  (222,
#   0,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Jarid2 links MicroRNA and chromatin in Th17 cells.',
#   0),
#  (222,
#   1,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'In this issue of Immunity, Escobar et\xa0al.',
#   0),
#  (222,
#   2,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   '(2014) bring microRNAs and chromatin together by showing how activation-induced miR-155 targets the chromatin protein Jarid2 to regulate proinflammatory cytokine production in T helper 17 cells.',
#   1),
#  (222,
#   3,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'miR-155 activates cytokine gene expression in Th17 cells by regulating the DNA-binding protein Jarid2 to relieve polycomb-mediated repression.',
#   1),
#  (222,
#   4,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Mir155 was bound by Th17 cell transcription factors and was highly expressed during Th17 cell differentiation.',
#   0),
#  (222,
#   5,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'miR-155-deficient Th17 and T regulatory (Treg) cells expressed increased amounts of Jarid2, a DNA-binding protein that recruits the Polycomb Repressive Complex 2 (PRC2) to chromatin.',
#   1),
#  (222,
#   6,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'PRC2 binding to chromatin and H3K27 histone methylation was increased in miR-155-deficient cells, coinciding with failure to express Il22, Il10, Il9, and Atf3.',
#   0),
#  (222,
#   7,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Defects in Th17 cell cytokine expression and Treg cell homeostasis in the absence of Mir155 could be partially suppressed by Jarid2 deletion.',
#   0),
#  (222,
#   8,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Thus, miR-155 contributes to Th17 cell function by suppressing the inhibitory effects of Jarid2.',
#   1),
#  (222,
#   9,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Thus, miR-155 contributes to Th17 cell function by suppressing the inhibitory effects of Jarid2.',
#   1),
#  (222,
#   10,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Thus, miR-155 contributes to Th17 cell function by suppressing the inhibitory effects of Jarid2.',
#   0),
#  (222,
#   11,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Defects in Th17 cell cytokine expression and Treg cell homeostasis in the absence of Mir155 could be partially suppressed by Jarid2 deletion.',
#   0),
#  (222,
#   12,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Thus, miR-155 contributes to Th17 cell function by suppressing the inhibitory effects of Jarid2.',
#   0),
#  (222,
#   13,
#   'Is there any association between Jarid2 and miR-155 in Th17 cells?',
#   'Thus, miR-155 contributes to Th17 cell function by suppressing the inhibitory effects of Jarid2.',
#   0),
#  (4012,
#   0,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'The highly complex structure of the human brain is strongly shaped by genetic influences.',
#   1),
#  (4012,
#   1,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'Subcortical brain regions form circuits with cortical areas to coordinate movement, learning, memory and motivation, and altered circuits can lead to abnormal behaviour and disease.',
#   1),
#  (4012,
#   2,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'To investigate how common genetic variants affect the structure of these brain regions, here we conduct genome-wide association studies of the volumes of seven subcortical regions and the intracranial volume derived from magnetic resonance images of 30,717 individuals from 50 cohorts.',
#   1),
#  (4012,
#   3,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'We identify five novel genetic variants influencing the volumes of the putamen and caudate nucleus.',
#   1),
#  (4012,
#   4,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'We also find stronger evidence for three loci with previously established influences on hippocampal volume and intracranial volume.',
#   0),
#  (4012,
#   5,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'These variants show specific volumetric effects on brain structures rather than global effects across structures.',
#   0),
#  (4012,
#   6,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'The strongest effects were found for the putamen, where a novel intergenic locus with replicable influence on volume (rs945270; P = 1.08\u2009×\u200910(-33); 0.52% variance explained) showed evidence of altering the expression of the KTN1 gene in both brain and blood tissue.',
#   1),
#  (4012,
#   7,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'Variants influencing putamen volume clustered near developmental genes that regulate apoptosis, axon guidance and vesicle transport.',
#   0),
#  (4012,
#   8,
#   'Which subcortical brain structure is influenced the most by common genetic variants?',
#   'Identification of these genetic variants provides insight into the causes of variability in human brain development, and may help to determine mechanisms of neuropsychiatric dysfunction.',
#   0),
#  (566,
#   0,
#   'Oxantel is used for periodontitis treatment. How does it work?',
#   'Oxantel disrupts polymicrobial biofilm development of periodontal pathogens',
#   1),
#  (566,
#   1,
#   'Oxantel is used for periodontitis treatment. How does it work?',
#   'he anthelmintic drug oxantel has been shown to inhibit fumarate reductase (Frd) activity in some pathogenic bacteria and inhibit P. gingivalis homotypic biofilm formation.',
#   1),
#  (566,
#   2,
#   'Oxantel is used for periodontitis treatment. How does it work?',
#   'Oxantel, a cholinergic anthelmintic and fumarate reductase inhibitor, significantly inhibited biofilm formation by P. gingivalis and disrupted established biofilms at concentrations below its MIC against planktonic cells.',
#   1),
#  (1389,
#   0,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'These data reveal that the domain encoded by exon 9 is important to maintain telomere homeostasis and heterochromatin structure but does not play a role in DNA repair, thus pointing to other exons in the lamin A tail as responsible for the genomic instability phenotype in Lmna(Δ8-11/Δ8-11) mice',
#   1),
#  (1389,
#   1,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Lmna(Δ9/Δ9) MEFs exhibit telomere shortening and heterochromatin alterations but do not activate cathepsin L-mediated degradation of 53BP1 and maintain expression of BRCA1 and RAD51',
#   1),
#  (1389,
#   2,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Lamin A Δexon9 mutation leads to telomere and chromatin defects but not genomic instability',
#   0),
#  (1389,
#   3,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Caspase-6 gene disruption reveals a requirement for lamin A cleavage in apoptotic chromatin condensation',
#   0),
#  (1389,
#   4,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'The A- and B-type nuclear lamin networks: microdomains involved in chromatin organization and transcription.',
#   0),
#  (1389,
#   5,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Comparative genomic hybridization (CGH) analyses of microdissected blebs, fluorescence in situ hybridization (FISH), and immunofluorescence localization of modified histones demonstrate that gene-rich euchromatin associates with the LA/C blebs',
#   1),
#  (1389,
#   6,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Lamin A/C, caspase-6, and chromatin configuration during meiosis resumption in the mouse oocyte',
#   0),
#  (1389,
#   7,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Our results demonstrated that these proteins were always present and that their distributions were related to oocyte maturity, determined by chromatin configuration and oocyte diameter',
#   0),
#  (1389,
#   8,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Histone acetylation controls, almost exclusively, euchromatin protein dynamics; lamin A expression regulates heterochromatin protein dynamics, and G9a regulates both euchromatin and heterochromatin protein dynamics.',
#   0),
#  (1389,
#   9,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Histone acetylation controls, almost exclusively, euchromatin protein dynamics; lamin A expression regulates heterochromatin protein dynamics, and G9a regulates both euchromatin and heterochromatin protein dynamics.',
#   0),
#  (1389,
#   10,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Other proteins that reversibly interact with DNA, such as the lamins and nuclear pores, may have a role in the organization of DNA into transcribable euchromatin and nontranscribable heterochromatin.',
#   1),
#  (1389,
#   11,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Histone acetylation controls, almost exclusively, euchromatin protein dynamics; lamin A expression regulates heterochromatin protein dynamics, and G9a regulates both euchromatin and heterochromatin protein dynamics.',
#   0),
#  (1389,
#   12,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Other proteins that reversibly interact with DNA, such as the lamins and nuclear pores, may have a role in the organization of DNA into transcribable euchromatin and nontranscribable heterochromatin.',
#   1),
#  (1389,
#   13,
#   'Do A-type lamins bind euchromatin or heterochromatin?',
#   'Role for A-type lamins in herpesviral DNA targeting and heterochromatin modulation.',
#   0),
#  (409,
#   0,
#   'Does a linker histone exist in the yeast genome?',
#   'Hho1p is a bona fide linker histone',
#   0),
#  (409,
#   1,
#   'Does a linker histone exist in the yeast genome?',
#   'In Saccharomyces cerevisiae, HHO1 encodes a putative linker histone with very significant homology to histone H1',
#   1),
#  (409,
#   2,
#   'Does a linker histone exist in the yeast genome?',
#   'HHO1p may play a similar role to linker histones, but at restricted locations in the chromatin',
#   1),
#  (409,
#   3,
#   'Does a linker histone exist in the yeast genome?',
#   'The putative linker histone in Saccharomyces cerevisiae, Hho1p, has two regions of sequence (GI and GII) that are homologous to the single globular domains of linker histones H1 and H5 in higher eukaryotes.',
#   1),
#  (409,
#   4,
#   'Does a linker histone exist in the yeast genome?',
#   'The Saccharomyces cerevisiae homologue of the linker histone H1, Hho1p, has two domains that are similar in sequence to the globular domain of H1 (and variants such as H5)',
#   1),
#  (409,
#   5,
#   'Does a linker histone exist in the yeast genome?',
#   'Two homologous domains of similar structure but different stability in the yeast linker histone, Hho1p',
#   0),
#  (409,
#   6,
#   'Does a linker histone exist in the yeast genome?',
#   'Saccharomyces cerevisiae encodes a single linker histone, Hho1p, with two globular domains.',
#   0),
#  (409,
#   7,
#   'Does a linker histone exist in the yeast genome?',
#   'The Saccharomyces cerevisiae linker histone Hho1p, with two globular domains, can simultaneously bind to two four-way junction DNA molecules',
#   0),
#  (409,
#   8,
#   'Does a linker histone exist in the yeast genome?',
#   'Here, we show in yeast, that the presence of yeast linker histone Hho1p represses expression of a pol II transcribed gene (MET15) embedded in the rDNA.',
#   0),
#  (409,
#   9,
#   'Does a linker histone exist in the yeast genome?',
#   'Yeast linker histone Hho1p is required for efficient RNA polymerase I processivity and transcriptional silencing at the ribosomal DNA',
#   0),
#  (409,
#   10,
#   'Does a linker histone exist in the yeast genome?',
#   'Saccharomyces cerevisiae linker histone Hho1p is not essential for cell viability, and very little is known about its function in vivo.',
#   0),
#  (409,
#   11,
#   'Does a linker histone exist in the yeast genome?',
#   'Saccharomyces cerevisiae linker histone Hho1p functionally interacts with core histone H4 and negatively regulates the establishment of transcriptionally silent chromatin',
#   0),
#  (409,
#   12,
#   'Does a linker histone exist in the yeast genome?',
#   ' Unlike canonical linker histones in higher eukaryotes that have a single conserved globular domain, Hho1p possesses two globular domains.',
#   0),
#  (409,
#   13,
#   'Does a linker histone exist in the yeast genome?',
#   'We show that the carboxyl-terminal globular domain of Hho1p is dispensable for its function, suggesting that the mode of Hho1p action is similar to that of canonical linker histones',
#   0),
#  (409,
#   14,
#   'Does a linker histone exist in the yeast genome?',
#   'To identify new proteins involved in spore nuclear organization, we purified chromatin from mature spores and discovered a significant enrichment of the linker histone (Hho1)',
#   0),
#  (409,
#   15,
#   'Does a linker histone exist in the yeast genome?',
#   'Hho1 chromatin immunoprecipitation followed by sequencing (ChIP-seq) revealed increased genome-wide binding in mature spores and provides novel in vivo evidence of the linker histone binding to nucleosomal linker DNA',
#   0),
#  (409,
#   16,
#   'Does a linker histone exist in the yeast genome?',
#   'One of the peculiarities of S. cerevisiae cells is the unusual and less abundant linker histone, Hho1p.',
#   0),
#  (409,
#   17,
# ...
#   'Transgenic (TG) Ca/calmodulin-dependent protein kinase II (CaMKII)delta(C) mice have heart failure and isoproterenol (ISO)-inducible arrhythmias',
#   0),
#  (3223,
#   0,
#   'Name three binding partners of cofilin 2.',
#   'Cofilin-2 (Cfl2) was identified as one of the potential targets of miR-301a using prediction databases, which we validated by luciferase assay and mutation of predicted binding sites.',
#   1),
#  (3223,
#   1,
#   'Name three binding partners of cofilin 2.',
#   'In contrast to other isoforms, cofilin-2 efficiently binds and disassembles both ADP- and ATP/ADP-Pi-actin filaments.',
#   1),
#  (3223,
#   2,
#   'Name three binding partners of cofilin 2.',
#   'We mapped surface-exposed cofilin-2-specific residues required for ATP-actin binding and propose that these residues function as an "actin nucleotide-state sensor" among ADF/cofilins.',
#   1),
#  (2033,
#   0,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'METHODS: We analyzed patients from ARISTOTLE, a randomized trial of 18,201 patients with atrial fibrillation comparing the effects of apixaban versus warfarin on the risk of stroke or systemic embolism.',
#   0),
#  (2033,
#   1,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   ' In this study we evaluated the relationship between inflammatory biomarkers at baseline and future risk of cardiovascular events in the Apixaban for Reduction In Stroke and Other Thromboembolic Events in Atrial Fibrillation (ARISTOTLE) trial.METHODS: The ARISTOTLE trial randomised 18,201 patients with AF to apixaban or warfarin.',
#   1),
#  (2033,
#   2,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Moreover, apixaban was associated with decreased all-cause mortality (RR 0.89, 95% CI 0.81 to 0.99) although this finding was driven by the results of the ARISTOTLE trial.',
#   0),
#  (2033,
#   3,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Compared with warfarin, apixaban (in the ARISTOTLE trial) and edoxaban (in the ENGAGE-AF trial) were shown to be superior or non-inferior, respectively, for reduction in stroke or SE risk in patients with AF.',
#   0),
#  (2033,
#   4,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'METHODS: A decision-analytic Markov model was constructed to assess the cost-effectiveness of apixaban versus warfarin, based on data from the Apixaban for Reduction in Stroke and Other Thromboembolic Events in AF (ARISTOTLE) trial.',
#   1),
#  (2033,
#   5,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'The following phase 3 randomized trials with novel oral anticoagulants versus warfarin for stroke prevention in AF have been completed: the Randomized Evaluation of Long-term Anticoagulant therapy (RE-LY) trial with dabigatran, the Rivaroxaban Once daily oral direct Factor Xa inhibition Compared with vitamin K antagonism for prevention of stroke and Embolism Trial in Atrial Fibrillation (ROCKET-AF) trial with rivaroxaban, and the Apixaban for Reduction of Stroke and Other Thromboembolism Events in Atrial Fibrillation (ARISTOTLE) trial with apixaban.',
#   0),
#  (2033,
#   6,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'The following phase 3 randomized trials with novel oral anticoagulants versus warfarin for stroke prevention in AF have been completed: the Randomized Evaluation of Long-term Anticoagulant therapy (RE-LY) trial with dabigatran, the Rivaroxaban Once daily oral direct Factor Xa inhibition Compared with vitamin K antagonism for prevention of stroke and Embolism Trial in Atrial Fibrillation (ROCKET-AF) trial with rivaroxaban, and the Apixaban for Reduction of Stroke and Other Thromboembolism Events in Atrial Fibrillation (ARISTOTLE) trial with apixaban',
#   0),
#  (2033,
#   7,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'We sought to compare the efficacy and safety of the 3 new agents based on data from their published warfarin-controlled randomized trials, using the method of adjusted indirect comparisons.We included findings from 44 535 patients enrolled in 3 trials of the efficacy of dabigatran (Randomized Evaluation of Long-Term Anticoagulation Therapy [RELY]), apixaban (Apixaban for Reduction in Stroke and Other Thromboembolic Events in Atrial Fibrillation [ARISTOTLE]), and rivaroxaban (Rivaroxaban Once Daily Oral Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation [ROCKET-AF]), each compared with warfarin.',
#   0),
#  (2033,
#   8,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'A comparative analysis of three major clinical trials with factor Xa inhibitor oral anticoagulant (XOAC) drugs versus warfarin in atrial fibrillation-Rocket-AF (rivaroxaban), Aristotle (apixaban) and Engage AF Timi 48 (edoxaban; two different doses and sets of data)-was carried out.Data were extracted from the original reports (study level) and a meta-analysis was carried out.When compared with warfarin, XOAC therapy was associated with a decrease in haemorrhagic stroke, with a similar pattern for all regimens and meta-analysis showing a risk ratio of 0.488 (95% CI 0.',
#   0),
#  (2033,
#   9,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Apixaban compared with warfarin in patients with atrial fibrillation and previous stroke or transient ischaemic attack: a subgroup analysis of the ARISTOTLE trial.',
#   0),
#  (2033,
#   10,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Efficacy and safety of apixaban compared with warfarin for stroke prevention in patients with atrial fibrillation from East Asia: a subanalysis of the Apixaban for Reduction in Stroke and Other Thromboembolic Events in Atrial Fibrillation (ARISTOTLE) Trial.',
#   1),
#  (2033,
#   11,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Efficacy of apixaban when compared with warfarin in relation to renal function in patients with atrial fibrillation: insights from the ARISTOTLE trial.',
#   0),
#  (2033,
#   12,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'A comparative analysis of three major clinical trials with factor Xa inhibitor oral anticoagulant (XOAC) drugs versus warfarin in atrial fibrillation-Rocket-AF (rivaroxaban), Aristotle (apixaban) and Engage AF Timi 48 (edoxaban; two different doses and sets of data)-was carried out.Data were extracted from the original reports (study level) and a meta-analysis was carried out.When compared with warfarin, XOAC therapy was associated with a decrease in haemorrhagic stroke, with a similar pattern for all regimens and meta-analysis showing a risk ratio of 0.488 (95% C',
#   0),
#  (2033,
#   13,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'This study sought to characterize major bleeding on the basis of the components of the major bleeding definition, to explore major bleeding by location, to define 30-day mortality after a major bleeding event, and to identify factors associated with major bleeding.Apixaban was shown to reduce the risk of major hemorrhage among patients with atrial fibrillation in the ARISTOTLE (Apixaban for Reduction in Stroke and Other Thromboembolic Events in Atrial Fibrillation) trial.All patients who received at least 1 dose of a study drug were included.',
#   1),
#  (2033,
#   14,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Little is known about patients with 1 dose-reduction criterion who received the 5 mg twice daily dose of apixaban.To determine the frequency of 1 dose-reduction criterion and whether the effects of the 5 mg twice daily dose of apixaban on stroke or systemic embolism and bleeding varied among patients with 1 or no dose-reduction criteria.Among 18 201 patients in the ARISTOTLE trial, 17\u202f322 were included in this analysis.',
#   0),
#  (2033,
#   15,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'We sought to compare the efficacy and safety of the 3 new agents based on data from their published warfarin-controlled randomized trials, using the method of adjusted indirect comparisons.We included findings from 44 535 patients enrolled in 3 trials of the efficacy of dabigatran (Randomized Evaluation of Long-Term Anticoagulation Therapy [RELY]), apixaban (Apixaban for Reduction in Stroke and Other Thromboembolic Events in Atrial Fibrillation [ARISTOTLE]), and rivaroxaban (Rivaroxaban Once Daily Oral Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial i',
#   1),
#  (2033,
#   16,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'This study aimed to evaluate the medical cost reductions associated with the use of individual NOACs instead of warfarin from the US payer perspective.Rates for efficacy and safety clinical events for warfarin were estimated as the weighted averages from the RE-LY, ROCKET-AF and ARISTOTLE trials, and event rates for NOACs were determined by applying trial hazard ratios or relative risk ratios to such weighted averages.',
#   0),
#  (2033,
#   17,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'The ARISTOTLE trial showed apixaban was superior to warfarin for stroke prevention, significantly reduced all major bleeding, and resulted in a significant reduction in all-cause mortality.',
#   0),
#  (2033,
#   18,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'The following phase 3 randomized trials with novel oral anticoagulants versus warfarin for stroke prevention in AF have been completed: the Randomized Evaluation of Long-term Anticoagulant therapy (RE-LY) trial with dabigatran, the Rivaroxaban Once daily oral direct Factor Xa inhibition Compared with vitamin K antagonism for prevention of stroke and Embolism Trial in Atrial Fibrillation (ROCKET-AF) trial with rivaroxaban, and the Apixaban for Reduction of Stroke and Other Thromboembolism Events in Atrial Fibrillation (ARISTOTLE) trial with apixaban.',
#   0),
#  (2033,
#   19,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'In the ARISTOTLE trial, apixaban was superior to warfarin in the reduction of stroke or systemic embolism, major bleeding, intracranial hemorrhage, and all-cause mortality, with a similar reduction in the rate of ischemic stroke and better tolerability.',
#   0),
#  (2033,
#   20,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'The results of the ARISTOTLE trial, which is evaluating apixaban against warfarin in ∼18\u2009000 patients with AF, are expected to be available later this year.',
#   0),
#  (2033,
#   21,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'The Medco data did not contain information for patients receiving apixaban as it was not on the market at the time of analysis.RESULTS: Stroke and MB rates among RW NVAF patients during warfarin exposure were higher compared with event rates in patients treated with warfarin in ARISTOTLE (stroke: 5.29 vs.',
#   0),
#  (2033,
#   22,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'In the ARISTOTLE trial, apixaban when compared with warfarin reduced the rate of stroke, death, and bleeding.',
#   0),
#  (2033,
#   23,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'The ARISTOTLE trial compared apixaban with warfarin in 18 201 patients with AF and ≥ 1 additional risk factor for stroke.',
#   0),
#  (2033,
#   24,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Compared with warfarin, apixaban (in the ARISTOTLE trial) and edoxaban (in the ENGAGE-AF trial) were shown to be superior or non-inferior, respectively, for reduction in stroke or SE risk in patients with AF.',
#   0),
#  (2033,
#   25,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Efficacy and safety of apixaban compared with warfarin according to age for stroke prevention in atrial fibrillation: observations from the ARISTOTLE trial.',
#   0),
#  (2033,
#   26,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'Apixaban compared with warfarin in patients with atrial fibrillation and previous stroke or transient ischaemic attack: a subgroup analysis of the ARISTOTLE trial.',
#   0),
#  (2033,
#   27,
#   'Which two drugs were compared in the ARISTOTLE Trial?',
#   'In the ARISTOTLE trial, the rate of stroke or systemic embolism was reduced by apixaban compared with warfarin in patients with atrial fibrillation (AF).',
#   0),
#  (3796,
#   0,
#   'What does Retapamulin treat?',
#   ' the current study, we investigated the relationship between pleuromutilins, including valnemulin, tiamulin, and retapamulin, and 13 other antibiotics representing different mechanisms of action, against methicillin-susceptible and -resistant S. aureus',
#   0),
#  (3796,
#   1,
#   'What does Retapamulin treat?',
#   'Clinical and bacteriological efficacy of twice daily topical retapamulin ointment 1% in the management of impetigo and other uncomplicated superficial skin infections',
#   0),
#  (3796,
#   2,
#   'What does Retapamulin treat?',
#   'To determine clinical and bacteriological efficacy of retapamulin ointment 1% in treatment of patients with cutaneous bacterial infections caused by methicillin-resistant S. aureus (MRSA) and other bacteria.',
#   1),
#  (3796,
#   3,
#   'What does Retapamulin treat?',
#   ' Fusidic acid, mupirocin, and retapamulin cover methicillin-susceptible S. aureus and streptococcal infections.',
#   1),
#  (3796,
#   4,
#   'What does Retapamulin treat?',
#   'Treatment includes topical antibiotics such as mupirocin, retapamulin, and fusidic acid.',
#   0),
#  (3796,
#   5,
#   'What does Retapamulin treat?',
#   'topical retapamulin ointment 1% versus oral linezolid in the treatment of secondarily infected traumatic lesions and impetigo due to methicillin-resistant Staphylococcus aureus',
#   1),
#  (3796,
#   6,
#   'What does Retapamulin treat?',
#   ' To evaluate the clinical and bacteriological efficacy of topical retapamulin ointment 1% versus oral linezolid in the treatment of patients with secondarily infected traumatic lesions (SITLs; excluding abscesses) or impetigo due to methicillin-resistant Staphylococcus aureus (MRSA)',
#   0),
#  (3796,
#   7,
#   'What does Retapamulin treat?',
#   'Retapamulin is a semisynthetic pleuromutilin derivative being developed as a topical antibiotic for treating bacterial infections of the skin.',
#   0),
#  (3796,
#   8,
#   'What does Retapamulin treat?',
#   'OBJECTIVES: Retapamulin is the first agent of the pleuromutilin class formulated as a topical antibacterial for treating skin infections.',
#   0),
#  (3796,
#   9,
#   'What does Retapamulin treat?',
#   'Retapamulin appears to be a much needed antimicrobial option for treating the AD population due to their common carriage of bacterial pathogens and frequency of infectious complications.',
#   0),
#  (3796,
#   10,
#   'What does Retapamulin treat?',
#   'Retapamulin belongs to a newly developed class of antibiotics for the treatment of uncomplicated skin infections.',
#   0),
#  (3796,
#   11,
#   'What does Retapamulin treat?',
#   'Retapamulin: what is the role of this topical antimicrobial in the treatment of bacterial infections in atopic dermatitis?',
#   0),
#  (3796,
#   12,
#   'What does Retapamulin treat?',
#   'In vitro, retapamulin is highly potent against S. aureus and has a lower propensity to develop resistance than mupirocin.',
#   0),
#  (3796,
#   13,
#   'What does Retapamulin treat?',
#   '(twice-daily) dosing of retapamulin is highly effective against impetigo due to methicillin- susceptible S. aureus and Streptococcus pyogenes and may play an important role in limiting the development of resistance against systemic agents.',
#   0),
#  (3796,
#   14,
#   'What does Retapamulin treat?',
#   'In 2007, retapamulin was the first agent for human use approved in the pleuromutilin class of antibacterials in the United States (U.S.), and is the first topical antibacterial indicated to treat impetigo in over 20 years.',
#   0),
#  (3796,
#   15,
#   'What does Retapamulin treat?',
#   'Retapamulin: an antibacterial with a novel mode of action in an age of emerging resistance to Staphylococcus aureus.',
#   0),
#  ...]

# %%
devtest_set = []
for d in q_devtest:
    document_data = dataset[dataset['question'] == d]
    devtest_set += list(document_data.itertuples(index=False, name=None))
devtest_set
# Out:
# [(3953,
#   0,
#   'How many nucleotides long is the HOTAIR CNE?',
#   'HOTAIR was proposed to regulate either HoxD cluster genes in trans or HoxC cluster genes in cis, a mechanism that remains unclear.',
#   1),
#  (3953,
#   1,
#   'How many nucleotides long is the HOTAIR CNE?',
#   'We have identified a 32-nucleotide conserved noncoding element (CNE) as HOTAIR ancient sequence that likely originated at the root of vertebrate.',
#   1),
#  (3953,
#   2,
#   'How many nucleotides long is the HOTAIR CNE?',
#   'The second round of whole-genome duplication resulted in one copy of the CNE within HOTAIR and another copy embedded in noncoding transcript of HOXD11.',
#   1),
#  (3953,
#   3,
#   'How many nucleotides long is the HOTAIR CNE?',
#   'Paralogous CNEs underwent compensatory mutations, exhibit sequence complementarity with respect to transcripts directionality, and have high affinity in\xa0vitro.',
#   0),
#  (3953,
#   4,
#   'How many nucleotides long is the HOTAIR CNE?',
#   'The HOTAIR CNE resembled a poised enhancer in stem cells and an active enhancer in HOTAIR-expressing cells.',
#   1),
#  (3953,
#   5,
#   'How many nucleotides long is the HOTAIR CNE?',
#   'HOTAIR expression is positively correlated with HOXC11 in cis and negatively correlated with HOXD11 in trans.',
#   1),
#  (1512,
#   0,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Of 802 patients treated for craniosynostosis, 28 were identified with Pfeiffer syndrome: 17 were classified as type I (61 percent), seven were classified as type II (25 percent), and four were classified as type III (14 percent).',
#   0),
#  (1512,
#   1,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Pfeiffer syndrome is divided into three clinical subtypes.',
#   1),
#  (1512,
#   2,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Type 1 "classic" Pfeiffer syndrome involves individuals with mild manifestations including brachycephaly, midface hypoplasia and finger and toe abnormalities; it is associated with normal intelligence and generally good outcome.',
#   1),
#  (1512,
#   3,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Type 2 consists of cloverleaf skull, extreme proptosis, finger and toe abnormalities, elbow ankylosis or synostosis, developmental delay and neurological complications.',
#   1),
#  (1512,
#   4,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Type 3 is similar to type 2 but without a cloverleaf skull.',
#   1),
#  (1512,
#   5,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Recently, based on clinical findings, the disorder has been divided into three subtypes: type 1, characterized by mild expression; type 2, in which clover leaf skull deformity and multiple congenital anomalies are present at birth; and type 3, which is similar to type 2, but lacks the presence of the clover leaf skull at birth.',
#   0),
#  (1512,
#   6,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'It is a clinically variable disorder and has been divided into three subtypes [Cohen, 1993: Am J Med Genet 45:300-307].',
#   0),
#  (1512,
#   7,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Type 1 represents the less severe cases, while types 2 and 3 are the more severe cases.',
#   0),
#  (1512,
#   8,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'These latter types tend to have a higher risk for neurodevelopmental problems and a reduced life expectancy.',
#   0),
#  (1512,
#   9,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Classic Pfeiffer syndrome is designated type I.',
#   0),
#  (1512,
#   10,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Type 2 consists of cloverleaf skull with Pfeiffer hands and feet together with ankylosis of the elbows.',
#   0),
#  (1512,
#   11,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Such patients do poorly with an early death.',
#   0),
#  (1512,
#   12,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'All reported instances to date have been sporadic.',
#   0),
#  (1512,
#   13,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Type 3 is similar to type 2 but without cloverleaf skull.',
#   1),
#  (1512,
#   14,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Ocular proptosis is severe in degree and the anterior cranial base is markedly short.',
#   0),
#  (1512,
#   15,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'These patients also do poorly and tend to have an early death.',
#   0),
#  (1512,
#   16,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'To date all cases have occurred sporadically.',
#   0),
#  (1512,
#   17,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Although these 3 clinical subtypes do not have status as separate entities, their diagnostic and prognostic implications are important.',
#   0),
#  (1512,
#   18,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Type 1 is commonly associated with normal intelligence, generally good outcome, and can be found dominantly inherited in some families.',
#   0),
#  (1512,
#   19,
#   'Which are the subtypes of Pfeiffer syndrome?',
#   'Types 2 and 3 generally have severe neurological compromise, poor prognosis, early death, and sporadic occurrence.',
#   0),
#  (1887,
#   0,
#   'List the three most abundant bacterial phyla present in mouse feces.',
#   'Amplicons representing the major phyla encountered in the rumen (Firmicutes, 43.7%; Proteobacteria, 28.7%; Bacteroidetes, 25.3%; Spirochea, 1.1%, and Synergistes, 1.1%) were recovered,',
#   1),
#  (1887,
#   1,
#   'List the three most abundant bacterial phyla present in mouse feces.',
#   'alterations in the gut microbiota (increased Firmicutes and decreased Bacteroidetes)',
#   1),
#  (1887,
#   2,
#   'List the three most abundant bacterial phyla present in mouse feces.',
#   'The taxonomic analysis of the metagenomic reads indicated that pygmy loris fecal microbiomes were dominated by Bacteroidetes and Proteobacteria phyla.',
#   1),
#  (1887,
#   3,
#   'List the three most abundant bacterial phyla present in mouse feces.',
#   'Specifically, intermittent hypoxia-exposed mice showed a higher abundance of Firmicutes and a smaller abundance of Bacteroidetes and Proteobacteria phyla than controls.',
#   1),
#  (678,
#   0,
#   'List types of avoided words in bacterial genomes',
#   'Avoidance of palindromic words in bacterial and archaeal genomes: a close connection with restriction enzymes.',
#   0),
#  (678,
#   1,
#   'List types of avoided words in bacterial genomes',
#   'Short palindromic sequences (4, 5 and 6 bp palindromes) are avoided at a statistically significant level in the genomes of several bacteria, including the completely sequenced Haemophilus influenzae and Synechocystis sp.',
#   1),
#  (678,
#   2,
#   'List types of avoided words in bacterial genomes',
#   'genomes and in the complete genome of the archaeon Methanococcus jannaschii.',
#   1),
#  (678,
#   3,
#   'List types of avoided words in bacterial genomes',
#   'Palindromes corresponding to sites for restriction enzymes from other species are also avoided, albeit less significantly, suggesting that in the course of evolution bacterial DNA has been exposed to a wide spectrum of restriction enzymes, probably as the result of lateral transfer mediated by mobile genetic elements, such as plasmids and prophages',
#   1),
#  (678,
#   4,
#   'List types of avoided words in bacterial genomes',
#   'Palindromic words appear to accumulate in DNA once it becomes isolated from restriction-modification systems, as demonstrated by the case of organellar genomes',
#   1),
#  (678,
#   5,
#   'List types of avoided words in bacterial genomes',
#   'In certain cases, a comparison of avoided palindromic words in taxonomically related bacteria shows a pattern of relatedness of their R-M systems.',
#   0),
#  (678,
#   6,
#   'List types of avoided words in bacterial genomes',
#   'Recognition sites for type II restriction and modification enzymes in genomes of several bacteria are recognized as semi-palindromic motifs and are avoided at a significant degree.',
#   1),
#  (678,
#   7,
#   'List types of avoided words in bacterial genomes',
#   'On the basis of the set of most avoided words, and in accordance to the IUPAC coding standards, suggestions are made regarding potential recognition sequences.',
#   0),
#  (678,
#   8,
#   'List types of avoided words in bacterial genomes',
#   'In certain cases, a comparison of avoided palindromic words in taxonomically related bacteria shows a pattern of relatedness of their R-M systems.',
#   0),
#  (1051,
#   0,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'stem-loop structure called the selenocysteine incorporating sequence (SECIS)',
#   0),
#  (1051,
#   1,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "3'-UTR mRNA stem-loop termed SElenoCysteine Insertion Sequence (SECIS)",
#   1),
#  (1051,
#   2,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'Sec is inserted by a specific translational machinery that recognizes a stem-loop structure, the SECIS element',
#   0),
#  (1051,
#   3,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "Selenocysteine Insertion Sequence (SECIS) element in the 3'UTR of the transcript.",
#   1),
#  (1051,
#   4,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'The proximal stem-loop promotes Sec insertion',
#   0),
#  (1051,
#   5,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'Selenocysteine is encoded by an in-frame UGA codon specified by a stem-loop structure, the Sec insertion sequence element (SECIS)',
#   0),
#  (1051,
#   6,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "3' untranslated region RNA stem loop called a SEC incorporation sequence (SECIS)",
#   0),
#  (1051,
#   7,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "recoding of UGA as Sec depends on the selenocysteine insertion sequence (SECIS) element, a stem-loop structure in the 3' untranslated region of the transcript",
#   0),
#  (1051,
#   8,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "this requires a dedicated machinery comprising a stem-loop structure in the 3' UTR RNA (the SECIS element)",
#   0),
#  (1051,
#   9,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'RNA stem-loop structure, the SECIS element in the 3 untranslated region of (UTR) selenoprotein mRNAs',
#   0),
#  (1051,
#   10,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'recoding of the UGA stop codon to selenocysteine.',
#   0),
#  (1051,
#   11,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "In eukaryotes, this requires an RNA stem loop structure in the 3'-untranslated region, termed a selenocysteine insertion sequence (SECIS),",
#   0),
#  (1051,
#   12,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   ' insertion into proteins is directed by translational recoding of specific UGA codons located upstream of a stem-loop structure known as Sec insertion sequence (SECIS) element',
#   0),
#  (1051,
#   13,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "In eukaryotes, incorporation of Sec requires a Sec insertion sequence (SECIS) element, a stem-loop structure located in the 3'-untranslated regions of selenoprotein mRNAs",
#   0),
#  (1051,
#   14,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "selenocysteine insertion requires a cis-acting selenocysteine insertion sequence (SECIS) usually located in the 3'UTR of selenoprotein mRNAs",
#   1),
#  (1051,
#   15,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "The Sec insertion sequence (SECIS) element, which is the stem-loop structure present in 3' untranslated regions (UTRs) of eukaryotic selenoprotein-encoding genes",
#   0),
#  (1051,
#   16,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "For eukaryotic selenoprotein mRNAs, it has been proposed that a conserved stem-loop structure designated the Sec insertion sequence (SECIS) in the 3'-untranslated (3'-UTR) region is required for recognition of UGA as a Sec codon",
#   0),
#  (1051,
#   17,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "3'-untranslated regions of selenoprotein genes contain a common stem-loop structure, selenocysteine insertion sequence (SECIS) element, that is necessary for decoding UGA as selenocysteine",
#   0),
#  (1051,
#   18,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'Analyses of eukaryotic selenocysteine insertion sequence (SECIS) elements via computer folding programs, mutagenesis studies, and chemical and enzymatic probing has led to the derivation of a predicted consensus structural model for these elements.',
#   0),
#  (1051,
#   19,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'This model consists of a stem-loop or hairpin',
#   0),
#  (1051,
#   20,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "ECIS elements form stem-loop structures in the 3' untranslated regions (UTR) of eukaryotic mRNAs that encode selenoproteins",
#   0),
#  (1051,
#   21,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'We report a detailed experimental study of the secondary structures of the SECIS elements',
#   0),
#  (1051,
#   22,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'It is characterized by a stem-loop structure',
#   0),
#  (1051,
#   23,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   " in eukaryotic selenoprotein mRNAs, this stem-loop structure, the selenocysteine insertion sequence (SECIS) element, resides in the 3'-untranslated region",
#   1),
#  (1051,
#   24,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "ECIS elements are stem-loop structures located in the 3' untranslated regions (UTRs) of eukaryotic selenoprotein mRNAs",
#   0),
#  (1051,
#   25,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   "eukaryotic selenocysteine UGA codons requires a stem-loop structure in the 3'UTR of mRNAs, the selenocysteine insertion sequence (SECIS) element",
#   1),
#  (1051,
#   26,
#   "What is the name of the stem loop present in the 3' end of genes encoding for selenoproteins?",
#   'stem-loops and critical nucleotides similar to those in the SECIS elements',
#   0),
#  (2794,
#   0,
#   'Are ultraconserved enhancers important for normal development?',
#   'Ultraconserved Enhancers Are Required for Normal Development.',
#   1),
#  (2794,
#   1,
#   'Are ultraconserved enhancers important for normal development?',
#   'However, initial deletion studies in mice revealed that loss of such extraordinarily constrained sequences had no immediate impact on viability.',
#   1),
#  (2794,
#   2,
#   'Are ultraconserved enhancers important for normal development?',
#   'Here, we show that ultraconserved enhancers are required for normal development.',
#   1),
#  (2794,
#   3,
#   'Are ultraconserved enhancers important for normal development?',
#   'Here, we show that ultraconserved enhancers are required for normal development.',
#   1),
#  (463,
#   0,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol inhibits mTOR signaling by promoting the interaction between mTOR and DEPTOR',
#   0),
#  (463,
#   1,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Here, we show that RSV inhibits insulin- and leucine-stimulated mTOR signaling in C2C12 fibroblasts via a Sirt1-independent mechanism',
#   0),
#  (463,
#   2,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Treating C2C12 cells with RSV dramatically inhibited insulin-stimulated Akt, S6 kinase, and 4E-BP1 phosphorylation but had little effect on tyrosine phosphorylation of the insulin receptor and activation of the p44/42 MAPK signaling pathway',
#   0),
#  (463,
#   3,
#   'What is the effect of resveratrol on mTOR activity?',
#   'RSV treatment also partially blocked mTOR and S6 kinase phosphorylation in TSC1/2-deficient mouse embryonic fibroblasts, suggesting the presence of an inhibitory site downstream of TSC1/2',
#   0),
#  (463,
#   4,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Taken together, our studies reveal that RSV inhibits leucine-stimulated mTORC1 activation by promoting mTOR/DEPTOR interaction and thus uncover a novel mechanism by which RSV negatively regulates mTOR activity',
#   1),
#  (463,
#   5,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Recent studies suggest that modulation of the mTOR signalling pathway could play an important role in mediating the beneficial effects of RSV.',
#   0),
#  (463,
#   6,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol inhibits the mTOR mitogenic signaling evoked by oxidized LDL in smooth muscle cells',
#   0),
#  (463,
#   7,
#   'What is the effect of resveratrol on mTOR activity?',
#   'esveratrol blocked the oxLDL-induced phosphorylation and activation of the PI3K/Akt/mTOR/p70S6K pathway and strongly inhibited both the DNA synthesis and proliferation of SMC',
#   0),
#  (463,
#   8,
#   'What is the effect of resveratrol on mTOR activity?',
#   'At concentrations that inhibit mTOR, resveratrol suppresses cellular senescence',
#   0),
#  (463,
#   9,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Here we demonstrated that, at cytostatic, near-toxic concentrations, resveratrol inhibited S6 phosphorylation and prevented the senescence morphology in human cells',
#   0),
#  (463,
#   10,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol downregulates PI3K/Akt/mTOR signaling pathways in human U251 glioma cells',
#   1),
#  (463,
#   11,
#   'What is the effect of resveratrol on mTOR activity?',
#   'On the other hand, RSV significantly increased the association between mTOR and its inhibitor, DEPTOR',
#   0),
#  (463,
#   12,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol inhibits mTOR signaling by targeting DEPTOR',
#   0),
#  (463,
#   13,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Recent studies suggest that suppressing the signaling pathway mediated by mTOR, a well-known energy sensor that integrates various hormonal, nutrient and environmental signals to regulate cell growth, metabolism and survival, could play an important role in mediating the beneficial effect of RSV',
#   0),
#  (463,
#   14,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol engages AMPK to attenuate ERK and mTOR signaling in sensory neurons and inhibits incision-induced acute and chronic pain',
#   0),
#  (463,
#   15,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Our results demonstrate that resveratrol profoundly inhibits ERK and mTOR signaling in sensory neurons in a time- and concentration-dependent fashion and that these effects are mediated by AMPK activation and independent of sirtuin activity',
#   0),
#  (463,
#   16,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol enhances the antitumor effects of temozolomide in glioblastoma via ROS-dependent AMPK-TSC-mTOR signaling pathway',
#   0),
#  (463,
#   17,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol enhances the anti-tumor activity of the mTOR inhibitor rapamycin in multiple breast cancer cell lines mainly by suppressing rapamycin-induced AKT signaling.',
#   0),
#  (463,
#   18,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol inhibits mTOR signaling by promoting the interaction between mTOR and DEPTOR.',
#   0),
#  (463,
#   19,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Consistent with the in vitro findings, resveratrol intervention in the PTEN knockout mouse model was associated with reduction in the prostatic levels of mTOR complex 1 (mTORC1) activity and increased expression of SIRT1.',
#   0),
#  (463,
#   20,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol inhibited the phosphorylation of PI3K, AKT and mTOR.',
#   0),
#  (463,
#   21,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol inhibits the mTOR mitogenic signaling evoked by oxidized LDL in smooth muscle cells.',
#   0),
#  (463,
#   22,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol also alleviated the PI3K/Akt/mTOR signaling by down-regulation of Akt phosphorylation and up-regulation of PTEN expression.',
#   0),
#  (463,
#   23,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol blocked the oxLDL-induced phosphorylation and activation of the PI3K/Akt/mTOR/p70S6K pathway and strongly inhibited both the DNA synthesis and proliferation of SMC.',
#   0),
#  (463,
#   24,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol reduced phosphorylation of ribosomal protein S6 and the mTOR inhibitor rapamycin further enhanced resveratrol-induced cell death.',
#   0),
#  (463,
#   25,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol downregulates PI3K/Akt/mTOR signaling pathways in human U251 glioma cells.',
#   1),
#  (463,
#   26,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Our results demonstrate that resveratrol profoundly inhibits ERK and mTOR signaling in sensory neurons in a time- and concentration-dependent fashion and that these effects are mediated by AMPK activation and independent of sirtuin activity.',
#   0),
#  (463,
#   27,
#   'What is the effect of resveratrol on mTOR activity?',
#   'The SIRT1 activator resveratrol reduces, whereas SIRT1 inhibitor nicotinamide enhances mTOR activity in a SIRT1 dependent manner.',
#   0),
#  (463,
#   28,
#   'What is the effect of resveratrol on mTOR activity?',
#   'We conclude that resveratrol is an inhibitor of global protein synthesis, and that this effect is mediated through modulation of mTOR-dependent and independent signaling.',
#   0),
#  (463,
#   29,
#   'What is the effect of resveratrol on mTOR activity?',
#   'RSV treatment has no effect on the expression levels of mTOR, raptor and DEPTOR, but greatly promotes the interaction between mTOR and its inhibitor DEPTOR.',
#   0),
#  (463,
#   30,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Taken together, our studies reveal that RSV inhibits leucine-stimulated mTORC1 activation by promoting mTOR/DEPTOR interaction and thus uncover a novel mechanism by which RSV negatively regulates mTOR activity.',
#   1),
#  (463,
#   31,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Furthermore, the inhibitory effect of RSV on leucine-stimulated mTOR signaling was greatly reduced in cells in which the expression levels of DEPTOR were suppressed by RNAi',
#   0),
#  (463,
#   32,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Consistent with the in vitro findings, resveratrol intervention in the PTEN knockout mouse model was associated with reduction in the prostatic levels of mTOR complex 1 (mTORC1) activity and increased expression of SIRT1',
#   0),
#  (463,
#   33,
#   'What is the effect of resveratrol on mTOR activity?',
#   'The SIRT1 activator resveratrol reduces, whereas SIRT1 inhibitor nicotinamide enhances mTOR activity in a SIRT1 dependent manner',
#   0),
#  (463,
#   34,
#   'What is the effect of resveratrol on mTOR activity?',
#   'However, most frequently, RSV is found to inhibit the activity of the mTOR pathway proteins, and to activate AMPK and LKB1, which can suppress mTOR signalling',
#   0),
#  (463,
#   35,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Over the past few years, numerous studies have suggested that suppressing the activity of mammalian target of rapamycin (mTOR), a critical regulator of cell metabolism, growth, and proliferation, may provide a key mechanism underlying the anticarcinogenic properties of resveratrol',
#   0),
#  (463,
#   36,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol blocks specifically this pathway, thereby inhibiting oxLDL-induced SMC proliferation.',
#   0),
#  (463,
#   37,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol causes cell cycle arrest and induces apoptotic cell death in various types of cancer cells',
#   0),
#  (463,
#   38,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol decreased both the expression and phosphorylation of Akt',
#   0),
#  (463,
#   39,
#   'What is the effect of resveratrol on mTOR activity?',
#   ' Modulation of the AMPK, Akt and mTOR pathways',
#   0),
#  (463,
#   40,
#   'What is the effect of resveratrol on mTOR activity?',
#   'RSV (2.5-5 μM) inhibited clonogenic survival of PC3 and 22RV1 cells but not of normal prostate PNT1A cells',
#   0),
#  (463,
#   41,
#   'What is the effect of resveratrol on mTOR activity?',
#   'RSV enhanced IR-activation of ATM and AMPK but inhibited basal and IR-induced phosphorylation of Akt',
#   0),
#  (463,
#   42,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Our results suggest that RSV arrests cell cycle, promotes apoptosis and sensitizes PrCa cells to IR likely through a desirable dual action to activate the ATM-AMPK-p53-p21(cip1)/p27(kip1) and inhibit the Akt signalling pathways',
#   0),
#  (463,
#   43,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Resveratrol pre-treatment reduces early inflammatory responses induced by status epilepticus via mTOR signaling',
#   0),
#  (463,
#   44,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Over the past few years, numerous studies have suggested that suppressing the activity of mammalian target of rapamycin (mTOR), a critical regulator of cell metabolism, growth, and proliferation, may provide a key mechanism underlying the anticarcinogenic properties of resveratrol.',
#   0),
#  (463,
#   45,
#   'What is the effect of resveratrol on mTOR activity?',
#   'It has been found that resveratrol targets multiple components of the phosphatidylinositol 3- kinase(PI3K)/Akt and mTOR signaling pathways, including PI3K, Akt, PTEN, and DEPTOR, suggesting that this natural compound and its derivatives may offer a promising new cancer treatment.',
#   1),
#  (463,
#   46,
#   'What is the effect of resveratrol on mTOR activity?',
#   'Autophagic cell death induced by resveratrol depends on the Ca(2+)/AMPK/mTOR pathway in A549 cells',
#   0),
#  (463,
#   47,
#   'What is the effect of resveratrol on mTOR activity?',
#   'In conclusion, we demonstrate that resveratrol-induced A549 cell death was mediated by the process of autophagic cell death via Ca(2+)/AMPK-mTOR signaling pathway.',
#   0),
#  (1725,
#   0,
#   'What is a disordered protein?',
#   'Intrinsically disordered proteins (IDPs) are ubiquitously involved in cellular processes and often implicated in human pathological conditions.',
#   1),
#  (1725,
#   1,
#   'What is a disordered protein?',
#   'The critical biological roles of these proteins, despite not adopting a well-defined fold, encouraged structural biologists to revisit their views on the protein structure-function paradigm.',
#   0),
#  (1725,
#   2,
#   'What is a disordered protein?',
#   'Intrinsically disordered proteins (IDPs) frequently function in protein interaction networks that regulate crucial cellular signaling pathways.',
#   1),
#  (1725,
#   3,
#   'What is a disordered protein?',
#   'Many IDPs undergo transitions from disordered conformational ensembles to folded structures upon binding to their cellular targets.',
#   1),
#  (1725,
#   4,
#   'What is a disordered protein?',
#   'The intrinsically disordered protein (IDP) stathmin plays an important regulatory role in cytoskeletal maintenance through its helical binding to tubulin and microtubules.',
#   0),
#  (1725,
#   5,
#   'What is a disordered protein?',
#   'However, it lacks a stable fold in the absence of its binding partner.',
#   0),
#  (1725,
#   6,
#   'What is a disordered protein?',
#   'Intrinsically disordered proteins lack stable tertiary and/or secondary structures under physiological conditions in vitro.',
#   1),
#  (1725,
#   7,
#   'What is a disordered protein?',
#   'Intrinsically disordered proteins undergo significant conformational transitions to well folded forms only on binding to partner.',
#   1),
#  (1725,
#   8,
#   'What is a disordered protein?',
#   'DisCons is an openly accessible sequence analysis tool that identifies and highlights structurally disordered segments of proteins where the conformational flexibility is conserved across homologs, and therefore potentially functional.',
#   0),
#  (2851,
#   0,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Here, we identify TIAM1 as a critical antagonist of CRC progression through inhibiting TAZ and YAP, effectors of WNT signaling.',
#   1),
#  (2851,
#   1,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'We demonstrate that TIAM1 shuttles between the cytoplasm and nucleus antagonizing TAZ/YAP by distinct mechanisms in the two compartments.',
#   0),
#  (2851,
#   2,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'In the cytoplasm, TIAM1 localizes to the destruction complex and promotes TAZ degradation by enhancing its interaction with βTrCP.',
#   0),
#  (2851,
#   3,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Nuclear TIAM1 suppresses TAZ/YAP interaction with TEADs, inhibiting expression of TAZ/YAP target genes implicated in epithelial-mesenchymal transition, cell migration, and invasion, and consequently suppresses CRC cell migration and invasion.',
#   0),
#  (2851,
#   4,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Importantly, high nuclear TIAM1 in clinical specimens associates with increased CRC patient survival.',
#   0),
#  (2851,
#   5,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Together, our findings suggest that in CRC TIAM1 suppresses tumor progression by regulating YAP/TAZ activity.',
#   1),
#  (2851,
#   6,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Together, our findings suggest that in CRC TIAM1 suppresses tumor progression by regulating YAP/TAZ activity.',
#   1),
#  (2851,
#   7,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Nuclear TIAM1 suppresses TAZ/YAP interaction with TEADs, inhibiting expression of TAZ/YAP target genes implicated in epithelial-mesenchymal transition, cell migration, and invasion, and consequently suppresses CRC cell migration and invasion.',
#   0),
#  (2851,
#   8,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Using an orthotopic xenograft model in nude mice, we confirmed that Tiam1 silencing could reduce tumor growth by subcutaneous injection and could suppress lung and liver metastases of colorectal cancer cells.',
#   1),
#  (2851,
#   9,
#   'Is TIAM1 favoring tumor progression in colorectal cancer (CRC)?',
#   'Together, our findings suggest that in CRC TIAM1 suppresses tumor progression by regulating YAP/TAZ activity.<br>',
#   1),
#  (1362,
#   0,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'The type 1 protein phosphatase (PP1) is a critical negative regulator of Ca(2+) cycling and contractility in the cardiomyocyte.',
#   0),
#  (1362,
#   1,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'In particular, it mediates restoration of cardiac function to basal levels, after beta-adrenergic stimulation, by dephosphorylating key phospho-proteins.',
#   0),
#  (1362,
#   2,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'PP1 is a holoenzyme comprised of its catalytic and auxiliary subunits.',
#   0),
#  (1362,
#   3,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   "These regulatory proteins dictate PP1's subcellular localization, substrate specificity and activity.",
#   0),
#  (1362,
#   4,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Amongst them, inhibitor-1 is of particular importance since it has been implicated as an integrator of multiple neurohormonal pathways, which finely regulate PP1 activity, at the level of the sarcoplasmic reticulum (SR).',
#   0),
#  (1362,
#   5,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'In fact, perturbations in the regulation of PP1 by inhibitor-1 have been implicated in the pathogenesis of heart failure, suggesting that inhibitor-1-based therapeutic interventions may ameliorate cardiac dysfunction and remodeling in the failing heart.',
#   0),
#  (1362,
#   6,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Aberrant beta-adrenergic signaling and depressed calcium homeostasis, associated with an imbalance of protein kinase A and phosphatase-1 activities, are hallmarks of heart failure.',
#   0),
#  (1362,
#   7,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Phosphatase-1 is restrained by its endogenous inhibitor, protein phosphatase inhibitor-1 (PPI-1)',
#   0),
#  (1362,
#   8,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Using this technology, we showed that inhibition of the protein phosphatase 1, by its constitutively active inhibitor-1, significantly increases cardiac contractility and calcium handling.',
#   0),
#  (1362,
#   9,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Thus, long-term cardiac specific overexpression of the protein phosphatase 1 inhibitor-1 and the associated increases in cardiac contractility appear to herald changes in a rather small number of proteins, which may reflect important compensatory adaptations in a hyperdynamic heart [corrected]',
#   0),
#  (1362,
#   10,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Inhibitor-1 becomes a potent inhibitor of protein phosphatase 1 when phosphorylated by cAMP-dependent protein kinase at Thr(35).',
#   1),
#  (1362,
#   11,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Moreover, Ser(67) of inhibitor-1 serves as a substrate for cyclin-dependent kinase 5 in the brain.',
#   0),
#  (1362,
#   12,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Inhibitor 1 (I-1) is a protein inhibitor of protein phosphatase 1 (PP1), a major eukaryotic Ser/Thr phosphatase.',
#   1),
#  (1362,
#   13,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Nonphosphorylated I-1 is inactive, whereas phosphorylated I-1 is a potent PP1 inhibitor.',
#   0),
#  (1362,
#   14,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Ser67-phosphorylated inhibitor 1 is a potent protein phosphatase 1 inhibitor.',
#   0),
#  (1362,
#   15,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'PP1 activity was inhibited by protamine, heparin, okadaic acid (IC50 50 nM) and mammalian inhibitor-1 (IC50 2 nM).',
#   0),
#  (1362,
#   16,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'On the other hand.',
#   0),
#  (1362,
#   17,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'The cDNA encoding human brain protein phosphatase inhibitor-1 (I-1) was expressed in Escherichia coli.',
#   0),
#  (1362,
#   18,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Following PKA phosphorylation at a threonine, recombinant human I-1 was indistinguishable from rabbit skeletal muscle I-1 as a potent and specific inhibitor of the type-1 protein serine/threonine phosphatase (PP1).',
#   0),
#  (1362,
#   19,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'N-Terminal phosphopeptides of I-1 that retained the selectivity of intact human I-1 highlighted a functional domain that mediates PP1 inhibition.',
#   0),
#  (1362,
#   20,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Protein phosphatase inhibitor-1 was purified from bovine adipose tissue.',
#   0),
#  (1362,
#   21,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   "The protein had an apparent molecular mass of 32 kDa by SDS/PAGE and a Stokes' radius of 3.4 nm.",
#   0),
#  (1362,
#   22,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'It was phosphorylated by cAMP-dependent protein kinase on a threonyl residue; this phosphorylation was necessary for inhibition of protein phosphatase-1.',
#   0),
#  (1362,
#   23,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Bovine adipose tissue inhibitor-1 was compared directly with rabbit skeletal muscle inhibitor-1 and with a 32000-Mr, dopamine- and cAMP-regulated phosphoprotein from bovine brain (DARPP-32), also an inhibitor of protein phosphatase-1.',
#   0),
#  (1362,
#   24,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Protein inhibitor-1 (I-1) specifically inhibits protein phosphatase 1 (PP1), the predominant PLB phosphatase in heart.',
#   0),
#  (1362,
#   25,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Inhibitor 1 (I-1) is a protein inhibitor of protein phosphatase 1 (PP1), the predominating Ser/Thr phosphatase in the heart.',
#   1),
#  (1362,
#   26,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Inhibitor-1 (I-1) is a selective inhibitor of protein phosphatase-1 (PP1) and regulates several PP1-dependent signaling pathways, including cardiac contractility and regulation of learning and memory.',
#   0),
#  (1362,
#   27,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Inhibitor 1 (I-1) is a protein inhibitor of protein phosphatase 1 (PP1), a major eukaryotic Ser/Thr phosphatase.',
#   1),
#  (1362,
#   28,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Inhibitor 1 (I-1) is a protein inhibitor of protein phosphatase 1 (PP1), the predominating Ser/Thr phosphatase in the heart',
#   1),
#  (1362,
#   29,
#   'Which protein is the main inhibitor of protein phosphatase 1 (PP1)?',
#   'Protein inhibitor-1 (I-1) specifically inhibits protein phosphatase 1 (PP1), the predominant PLB phosphatase in heart',
#   0),
#  (990,
#   0,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'Dracorhodin perchlorate induced human breast cancer MCF-7 apoptosis through mitochondrial pathways.',
#   0),
#  (990,
#   1,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'It was reported that DP could induce apoptosis in human prostate cancer, human gastric tumor cells and human melanoma, but the cytotoxic effect of DP on human breast cancer was not investigated.',
#   1),
#  (990,
#   2,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'CONCLUSION: Therefore DP was a candidate for anti-breast cancer, DP induced apoptosis of MCF-7 through mitochondrial pathway.',
#   0),
#  (990,
#   3,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'Dracorhodin perchlorate has been recently shown to induce apoptotic cell death in cancer cells.',
#   0),
#  (990,
#   4,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'However, the molecular mechanisms underlying these effects are unknown in human gastric tumor cells.',
#   0),
#  (990,
#   5,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'Dracorhodin perchlorate suppresses proliferation and induces apoptosis in human prostate cancer cell line PC-3.',
#   0),
#  (990,
#   6,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'The growth inhibition and pro-apoptosis effects of dracorhodin perchlorate on human prostate cancer PC-3 cell line were examined.',
#   0),
#  (990,
#   7,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'Dracorhodin perchlorate, an anthocyanin red pigment, induces human premyelocytic leukemia HL-60 cell death through apoptotic pathway.',
#   0),
#  (990,
#   8,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'Dracorhodin perchlorate, an anthocyanin red pigment, induces human melanoma A375-S2 cell death through the apoptotic pathway.',
#   0),
#  (990,
#   9,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'Dracorhodin perchlorate inhibited proliferation of several tumor cell lines.',
#   0),
#  (990,
#   10,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'The growth inhibition and pro-apoptosis effects of dracorhodin perchlorate on human prostate cancer PC-3 cell line were examined.',
#   0),
#  (990,
#   11,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'It was reported that DP could induce apoptosis in human prostate cancer, human gastric tumor cells and human melanoma, but the cytotoxic effect of DP on human breast cancer was not investigated.',
#   1),
#  (990,
#   12,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   ' Dracorhodin perchlorate (DP) was a synthetic analogue of the antimicrobial anthocyanin red pigment dracorhodin.',
#   0),
#  (990,
#   13,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'It was reported that DP could induce apoptosis in human prostate cancer, human gastric tumor cells and human melanoma, but the cytotoxic effect of DP on human breast cancer was not investigated.',
#   1),
#  (990,
#   14,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   ' The growth inhibition and pro-apoptosis effects of dracorhodin perchlorate on human prostate cancer PC-3 cell line were examined.',
#   0),
#  (990,
#   15,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'After administration of 10-80 μmol/L dracorhodin perchlorate for 12-48 h, cell viability of PC-3 cells was measured by MTT colorimetry.',
#   0),
#  (990,
#   16,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'It was reported that DP could induce apoptosis in human prostate cancer, human gastric tumor cells and human melanoma, but the cytotoxic effect of DP on human breast cancer was not investigated.',
#   1),
#  (990,
#   17,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'This study would investigate whether DP was a candidate chemical of anti-human breast cancer.',
#   0),
#  (990,
#   18,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'Dracorhodin perchlorate (DP) was a synthetic analogue of the antimicrobial anthocyanin red pigment dracorhodin.',
#   0),
#  (990,
#   19,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'It was reported that DP could induce apoptosis in human prostate cancer, human gastric tumor cells and human melanoma, but the cytotoxic effect of DP on human breast cancer was not investigated.',
#   1),
#  (990,
#   20,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'The growth inhibition and pro-apoptosis effects of dracorhodin perchlorate on human prostate cancer PC-3 cell line were examined.',
#   0),
#  (990,
#   21,
#   'Dracorhodin perchlorate was tested for treatment of which cancers?',
#   'After administration of 10-80 μmol/L dracorhodin perchlorate for 12-48 h, cell viability of PC-3 cells was measured by MTT colorimetry.',
#   0),
#  (1783,
#   0,
#   'What are the birth defects associated with Zika-virus infection?',
#   'the first time after the discovery of ZIKV, the Brazilian scientists are studying the possibility for the virus to cause severe congenital infection related to microcephaly and serious birth defects due to the time-spatial coincidence of the alarming increase of newborns with microcephaly and the Brazilian ZIKV epidemic.',
#   0),
#  (1783,
#   1,
#   'What are the birth defects associated with Zika-virus infection?',
#   ' Although a causal relationship between Zika infection during pregnancy and microcephaly is strongly suspected, such a connection has not yet been scientifically proven.',
#   1),
#  (1783,
#   2,
#   'What are the birth defects associated with Zika-virus infection?',
#   'a convincing association between Zika virus infection during pregnancy and birth defects, like microcephaly, among some of the newborns.',
#   1),
#  (1783,
#   3,
#   'What are the birth defects associated with Zika-virus infection?',
#   'counseling pregnant women on the risks of fetal microcephaly and other birth defects',
#   0),
#  (1783,
#   4,
#   'What are the birth defects associated with Zika-virus infection?',
#   'evidence suggests that congenital Zika virus infection is associated with microcephaly and other adverse pregnancy and infant outcomes.',
#   0),
#  (1783,
#   5,
#   'What are the birth defects associated with Zika-virus infection?',
#   'the virus has been linked to congenital malformations, including microcephaly and other severe neurological diseases, such as Guillain-Barré syndrome.',
#   0),
#  (1783,
#   6,
#   'What are the birth defects associated with Zika-virus infection?',
#   ' severe birth defects, such as microcephaly, have been linked to infection during early pregnancy.',
#   0),
#  (1783,
#   7,
#   'What are the birth defects associated with Zika-virus infection?',
#   'n can be prenatally passed from a pregnant woman to her fetus.',
#   0),
#  (1783,
#   8,
#   'What are the birth defects associated with Zika-virus infection?',
#   'There is sufficient evidence to conclude that intrauterine Zika virus infection is a cause of microcephaly and serious brain anomalies, but the full spectrum of anomalies has not been delineated.',
#   1),
#  (1783,
#   9,
#   'What are the birth defects associated with Zika-virus infection?',
#   'Although the full spectrum of adverse reproductive outcomes caused by Zika virus infection is not yet determined, a distinctive phenotype-the congenital Zika syndrome-has emerged.',
#   1),
#  (1783,
#   10,
#   'What are the birth defects associated with Zika-virus infection?',
#   'The current Zika virus (ZIKV) outbreak is associated with high numbers of human congenital birth defects',
#   0),
#  (1783,
#   11,
#   'What are the birth defects associated with Zika-virus infection?',
#   'However, ZIKV infection in early pregnancy has been associated with severe birth defects, including microcephaly and other developmental issues.',
#   0),
#  (1783,
#   12,
#   'What are the birth defects associated with Zika-virus infection?',
#   'Zika virus (ZIKV) infection is a new emerging threat around the globe which might be responsible for microcephaly and Guillain-Barre syndrome in the infants.',
#   0),
#  (1783,
#   13,
#   'What are the birth defects associated with Zika-virus infection?',
#   'Zika virus infection during pregnancy is a cause of microcephaly and other severe birth defects',
#   1),
#  (348,
#   0,
#   'What is the rate of survival after commotio cordis?',
#   'At their commotio cordis event, 216 study patients were 0.2-51 years old (mean age 15±9 years); 95% were males.',
#   1),
#  (348,
#   1,
#   'What is the rate of survival after commotio cordis?',
#   'Death occurred in 156 individuals (72%), while the other 60 (28%) survived.',
#   0),
#  (348,
#   2,
#   'What is the rate of survival after commotio cordis?',
#   'In the 2 groups, events were largely similar demographically, including frequency of survival (26% in U.S. vs 25%; P = .84),',
#   1),
#  (348,
#   3,
#   'What is the rate of survival after commotio cordis?',
#   'Survival of commotio cordis has risen from 10% to 15% since 2001.',
#   1),
#  (348,
#   4,
#   'What is the rate of survival after commotio cordis?',
#   'Only 21 (16%) individuals survived their event, with particularly prompt cardiopulmonary resuscitation/defibrillation (most commonly reversing ventricular fibrillation) the only identifiable factor associated with a favorable outcome.',
#   0),
#  (348,
#   5,
#   'What is the rate of survival after commotio cordis?',
#   'Survival rates for commotio cordis are low, even with prompt CPR and defibrillation.',
#   1),
#  (348,
#   6,
#   'What is the rate of survival after commotio cordis?',
#   'Survival is low, even when resuscitation is performed.',
#   1),
#  (1750,
#   0,
#   'Is synapsin a phosphoprotein?',
# ...
#   1),
#  (3919,
#   3,
#   'Describe SWItchMiner (SWIM)',
#   'Among them, a special subset of genes, called "switch genes", appears to be characterized by an unusual pattern of intra- and inter-module connections that confers them a crucial topological role, interestingly mirrored by the evidence of their clinic-biological relevance.',
#   1),
#  (3919,
#   4,
#   'Describe SWItchMiner (SWIM)',
#   'Here, we applied SWIM to a large panel of cancer datasets from The Cancer Genome Atlas, in order to highlight switch genes that could be critically associated with the drastic changes in the physiological state of cells or tissues induced by the cancer development.',
#   1),
#  (3919,
#   5,
#   'Describe SWItchMiner (SWIM)',
#   'We discovered that switch genes are found in all cancers we studied and they encompass protein coding genes and non-coding RNAs, recovering many known key cancer players but also many new potential biomarkers not yet characterized in cancer context.',
#   0),
#  (3919,
#   6,
#   'Describe SWItchMiner (SWIM)',
#   'Furthermore, SWIM is amenable to detect switch genes in different organisms and cell conditions, with the potential to uncover important players in biologically relevant scenarios, including but not limited to human cancer.',
#   0),
#  (1241,
#   0,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'Histone phosphorylation, ubiquitylation, SUMOylation and poly-ADP-ribosylation, as well as ATP-dependent nucleosome remodeling complexes, play equally pivotal roles in the maintenance of transcriptional fidelity',
#   1),
#  (1241,
#   1,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'oly(ADP-ribose) polymerase-1 (PARP-1; EC 2.4.2.30) is an abundant nuclear protein that is involved in DNA repair, cell cycle control, programmed cell death and transcriptional regulation.',
#   0),
#  (1241,
#   2,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'Many lines of evidence suggest that poly(ADP-ribose) polymerase-1 (Parp-1) is involved in transcriptional regulation of various genes as a coactivator or a corepressor by modulating chromatin structure',
#   1),
#  (1241,
#   3,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'These results suggest that Parp-1 is required to maintain transcriptional regulation of a wide variety of genes on a genome-wide scale',
#   0),
#  (1241,
#   4,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'PARP-1 was identified as a part of the mH2A1.1 nucleosome complex and was found to be associated with the Hsp70.1 promoter',
#   1),
#  (1241,
#   5,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'Upon heat shock, the Hsp70.1 promoter-bound PARP-1 is released to activate transcription through ADP-ribosylation of other Hsp70.1 promoter-bound proteins',
#   0),
#  (1241,
#   6,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'Cycloheximide-induced cells were treated with two chemical inhibitors of poly(ADP-ribose) polymerase.',
#   1),
#  (1241,
#   7,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   '3-Aminobenzamide inhibited 75% of PAP gene induction and 4-hydroxyquinazolone, the highly specific inhibitor of the enzyme, blocked almost completely PAP expression, suggesting that ADP-ribosylation was indeed required for the upregulation of PAP gene expression by cycloheximide',
#   0),
#  (1241,
#   8,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   ' inhibitors of poly(ADP-ribose) polymerase suppressed UV-induced HIV-1 gene expression but not tat-mediated expression',
#   1),
#  (1241,
#   9,
#   'Is poly (ADP- ribosylation) involved in transcriptional control?',
#   'oly(ADP-ribose) polymerase inhibitors suppress UV-induced human immunodeficiency virus type 1 gene expression',
#   0),
#  (1110,
#   0,
#   'Describe Malgaigne fracture.',
#   'Fractures of the transverse processes in the lumbar vertebrae occur as the result of major forces such as direct blunt trauma, violent lateral flexion-extension forces, avulsion of the psoas muscle, or Malgaigne fractures of the pelvis.',
#   0),
#  (1110,
#   1,
#   'Describe Malgaigne fracture.',
#   'The anteroposterior radiographic view revealed ununited fractures at the left superior and inferior pubic ramus, noted as a type I Malgaigne fracture.',
#   0),
#  (1110,
#   2,
#   'Describe Malgaigne fracture.',
#   'Posterior urethral injuries occur more commonly with vertically applied forces, which typically create Malgaigne-type fractures.',
#   0),
#  (1110,
#   3,
#   'Describe Malgaigne fracture.',
#   'Patients with bilateral pubic rami fractures or Malgaigne fractures were particularly prone to additional injuries; therefore, abdominal CT examinations are recommended in these patients.',
#   1),
#  (1110,
#   4,
#   'Describe Malgaigne fracture.',
#   'Pelvic fractures, especially those of a Malgaigne type, frequently occur in patients who are polytraumatized.',
#   1),
#  (1110,
#   5,
#   'Describe Malgaigne fracture.',
#   'The authours report the case of a 27-year-old man who had suffered a severe polytrauma with blunt thoracic injury, fracture of the lumbar spine, Malgaigne-type fracture of the pelvis and fracture of the femoral shaft on the right side, 10 years before.',
#   0),
#  (1110,
#   6,
#   'Describe Malgaigne fracture.',
#   'The paper deals with the displacement of the uterus observed during management of Malgaigne type pelvic fracture in a 33 years old female.',
#   0),
#  (1110,
#   7,
#   'Describe Malgaigne fracture.',
#   'This problem was first described by Malgaigne in 1857 in his classic article on double vertical fractures of the pelvis, in which he described a 34-year-old woman with a pelvic fracture who subsequently died during childbirth.',
#   0),
#  (1110,
#   8,
#   'Describe Malgaigne fracture.',
#   'Eleven cases of sacroiliac dislocation and/or fracture (Malgaigne pattern) were successfully reduced and stabilized using two threaded compression rods.',
#   0),
#  (1110,
#   9,
#   'Describe Malgaigne fracture.',
#   'We compared the mechanical performance of the Orthofix pelvic external fixator with that of the Pittsburgh triangular frame (PTF) on eight fresh-frozen cadaver pelves with experimentally created Malgaigne (double-vertical) fracture/dislocations.',
#   0),
#  (1110,
#   10,
#   'Describe Malgaigne fracture.',
#   'A 48-year-old woman developed symptomatic superior and inferior pubic rami fractures with a concomitant subluxation of the ipsilateral sacroiliac joint three years after pelvic irradiation for a gynecologic malignancy.',
#   1),
#  (1110,
#   11,
#   'Describe Malgaigne fracture.',
#   'Twenty-six of the thirty-two cadavera that were examined radiographically and dissected had a double break in the pelvic ring (Malgaigne pattern).',
#   0),
#  (1110,
#   12,
#   'Describe Malgaigne fracture.',
#   ' Initial hypotension, Malgaigne and bilateral pubic rami fractures, and blood requirements exceeding 2,000 cc were suggestive of abdominal trauma.',
#   1),
#  (1110,
#   13,
#   'Describe Malgaigne fracture.',
#   ' Malgaigne-type fractures with sacroiliac disruptions were created in four cadaver pelvises.',
#   1),
#  (1110,
#   14,
#   'Describe Malgaigne fracture.',
#   'The authors report 7 cases involving the surgical treatment of unstable pelvic ring fractures (Malgaigne type) using two compression bars, as described by Tile.',
#   0),
#  (1110,
#   15,
#   'Describe Malgaigne fracture.',
#   'Malgaigne fracture is referred to pelvic ring disruption at two sites, and is often treated surgically for its instability.',
#   0),
#  (1110,
#   16,
#   'Describe Malgaigne fracture.',
#   'Sacral fractures are generally accompanied by pelvic ring fractures.',
#   0),
#  (1110,
#   17,
#   'Describe Malgaigne fracture.',
#   'Malgaigne fracture is referred to pelvic ring disruption at two sites, and is often treated surgically for its instability.',
#   0),
#  (1110,
#   18,
#   'Describe Malgaigne fracture.',
#   'This problem was first described by Malgaigne in 1857 in his classic article on double vertical fractures of the pelvis, in which he described a 34-year-old woman with a pelvic fracture who subsequently died during childbirth',
#   0),
#  (1110,
#   19,
#   'Describe Malgaigne fracture.',
#   'The authors report 7 cases involving the surgical treatment of unstable pelvic ring fractures (Malgaigne type) using two compression bars, as described by Tile',
#   0),
#  (1110,
#   20,
#   'Describe Malgaigne fracture.',
#   'Another less frequently reported complication of pelvic fractures is the potential association with pregnancy and subsequent childbirth.',
#   0),
#  (1110,
#   21,
#   'Describe Malgaigne fracture.',
#   'This problem was first described by Malgaigne in 1857 in his classic article on double vertical fractures of the pelvis, in which he described a 34-year-old woman with a pelvic fracture who subsequently died during childbirth.',
#   0),
#  (1110,
#   22,
#   'Describe Malgaigne fracture.',
#   'This problem was first described by Malgaigne in 1857 in his classic article on double vertical fractures of the pelvis, in which he described a 34-year-old woman with a pelvic fracture who subsequently died during childbirth.',
#   0),
#  (1110,
#   23,
#   'Describe Malgaigne fracture.',
#   'A review of the literature reveals numerous articles addressing potential problems with parturition subsequent to a pelvic fracture and several articles dealing with pelvic fractures occurring during pregnancy.',
#   0),
#  (1110,
#   24,
#   'Describe Malgaigne fracture.',
#   'The authors report 7 cases involving the surgical treatment of unstable pelvic ring fractures (Malgaigne type) using two compression bars, as described by Tile.',
#   0),
#  (1110,
#   25,
#   'Describe Malgaigne fracture.',
#   'This problem was first described by Malgaigne in 1857 in his classic article on double vertical fractures of the pelvis, in which he described a 34-year-old woman with a pelvic fracture who subsequently died during childbirth.',
#   0),
#  (3477,
#   0,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'Nucleosome arrays inhibit both initiation and elongation of transcripts',
#   1),
#  (3477,
#   1,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   ' Both transcript initiation and elongation were inhibited, the extent of the inhibition being directly proportional to the number of nucleosome cores reconstituted onto the pT207-18 DNA templates.',
#   1),
#  (3477,
#   2,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'neither partial nor complete dissociation of the histone octamer is essential for transcription elongation through arrays of nucleosome cores in vitro.',
#   0),
#  (3477,
#   3,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'The high affinity of histones for single-stranded DNA observed in titration experiments performed using the purified (+) and (-) strands of the NX1 fragment suggests that nucleosome dissociation is not due to the formation of segments of single-stranded DNA by RNA polymerase in the elongation process',
#   0),
#  (3477,
#   4,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'These effects are especially pronounced on chromatin templates, where both transcription initiation and elongation are virtually halted.',
#   1),
#  (3477,
#   5,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'The inhibition of transcription elongation appears to result from a dramatic increase in premature termination of transcripts.',
#   0),
#  (3477,
#   6,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'By using this system, we show that BRG1, the enzymatic motor of the SWI-SNF chromatin-remodelling complex, is recruited to the positioned nucleosome in a transcription elongation-dependent manner and facilitates traversal of the nucleosome by RNAPII.',
#   1),
#  (3477,
#   7,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'in order to elongate their products, both DNA and RNA polymerases must be able to overcome the inhibition presented by chromatin',
#   1),
#  (3477,
#   8,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   ' We suggest a three-step model in which nucleosome remodelers, general transcription factors, and the transcriptional elongation machinery are primarily involved in generating the nucleosome positioning pattern in\xa0vivo.',
#   0),
#  (3477,
#   9,
#   'How is transcriptional elongation affected by nucleosome positioning?',
#   'The independent effect of lack of TFIIS on nucleosome occupancy and fuzziness supports the existence of alternative chromatin dynamics during transcription elongation.',
#   0),
#  (3812,
#   0,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'Prolonged survival in secondary glioblastoma following local injection of targeted alpha therapy with',
#   1),
#  (3812,
#   1,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   '[Radiation induced glioblastoma: a case report].',
#   0),
#  (3812,
#   2,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'We report a surgical case of a 54-year-old woman with a radiation induced glioblastoma.',
#   0),
#  (3812,
#   3,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'Glioblastoma multiforme following cranial irradiation and chemotherapy for acute lymphocytic leukaemia.',
#   0),
#  (3812,
#   4,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'The occurrence of glioblastoma multiforme following radiation and chemotherapy in acute lymphocytic leukaemia (ALL) is rare.',
#   0),
#  (3812,
#   5,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'Glioblastoma multiforme following cranial irradiation and chemotherapy for acute lymphocytic leukaemia.',
#   0),
#  (3812,
#   6,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'R',
#   0),
#  (3812,
#   7,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'exact cause for the development of glioblastoma multiforme following therapy for ALL is not clear.',
#   1),
#  (3812,
#   8,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'A gen',
#   0),
#  (3812,
#   9,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'ndary malignant and benign brain tumors such as astrocytoma, meningioma and glioblastoma have been described in long-term survivors of conventional myeloablative alloBMT.',
#   0),
#  (3812,
#   10,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'Here w',
#   0),
#  (3812,
#   11,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'The authors consider irradiation-induced glioblastomas secondary to primarily verified medulloblastomas in patients who had previously undergone craniospinal irradiation as a component of combined treatment after tumor resection.',
#   0),
#  (3812,
#   12,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'The authors analyzed patterns of occurrence of irradiation-induced glioblastomas depending on the molecular genetic group and clinical characteristics of patients after primary surgery.',
#   0),
#  (3812,
#   13,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'Secondary brain tumors rarely arise after cranial irradiation; among them, meningiomas and glioblastomas are the most common and secondary oligodendroglial tumors the most rare.',
#   1),
#  (3812,
#   14,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'Secondary glioblastoma multiforme (sGBM) can occur after a long latency period following radiation treatment of various diseases including brain tumors, leukemia, and more benign disorders like tinea capitis.',
#   1),
#  (3812,
#   15,
#   'Can secondary glioblastoma be caused by brain irradiation?',
#   'Irradiation, however, acts as an oncogenic factor as a delayed effect and it is rare that glioblastoma multiforme develops during the remission period of ALL.',
#   0),
#  ...]

# %%
test_set = []
for d in q_test:
    document_data = dataset[dataset['question'] == d]
    test_set += list(document_data.itertuples(index=False, name=None))
test_set
# Out:
# [(269,
#   0,
#   'What medication were compared in the ROCKET AF Trial?',
#   'METHODS AND RESULTS: Patients randomized in the Rivaroxaban Once Daily Oral Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET-AF) trial (n = 14 264) were grouped by baseline AF category: paroxysmal or persistent.',
#   0),
#  (269,
#   1,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Multivariable adjustment was performed to compare thrombo-embolic events, bleeding, and death between groups, in high-risk subgroups, and across treatment assignment (rivaroxaban or warfarin).',
#   0),
#  (269,
#   2,
#   'What medication were compared in the ROCKET AF Trial?',
#   'This review focuses on the direct Factor Xa inhibitor rivaroxaban, summarizing the properties that make rivaroxaban appropriate for anticoagulant therapy in this indication (including its predictable pharmacokinetic and pharmacodynamic profile and once-daily dosing regimen) and describing data from the Phase III ROCKET AF trial, which showed once-daily rivaroxaban to be noninferior to warfarin for the prevention of stroke in patients with nonvalvular AF.',
#   0),
#  (269,
#   3,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Subanalyses of ROCKET AF data showed rivaroxaban to have consistent efficacy and safety across a wide range of patients, and studies to confirm these results in real-world settings are underway.',
#   0),
#  (269,
#   4,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Rivaroxaban for stroke prevention in East Asian patients from the ROCKET AF trial.',
#   0),
#  (269,
#   5,
#   'What medication were compared in the ROCKET AF Trial?',
#   'CONCLUSIONS: Observed relative efficacy and safety of rivaroxaban versus warfarin were similar among patients within and outside East Asia.',
#   0),
#  (269,
#   6,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Rivaroxaban versus warfarin in Japanese patients with nonvalvular atrial fibrillation in relation to the CHADS2 score: a subgroup analysis of the J-ROCKET AF trial.',
#   0),
#  (269,
#   7,
#   'What medication were compared in the ROCKET AF Trial?',
#   'BACKGROUND: Results from a trial of rivaroxaban versus warfarin in 1280 Japanese patients with atrial fibrillation (J-ROCKET AF) revealed that rivaroxaban was noninferior to warfarin with respect to the principal safety outcome.',
#   0),
#  (269,
#   8,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Rivaroxaban, an oral direct factor Xa-inhibitor was non-inferior to adjusted dose warfarin in the prevention of stroke and embolism among patients with atrial fibrillation (AF) in the ROCKET-AF trial and has been approved for stroke prevention in AF.',
#   1),
#  (269,
#   9,
#   'What medication were compared in the ROCKET AF Trial?',
#   'The ROCKET AF trial compared rivaroxaban (20 mg/day; 15 mg/day in patients with creatinine clearance 30-49 ml/min) with dose-adjusted warfarin (international normalized ratio 2-3) in 14,264 patients with AF and a prior history of stroke or at least two other additional risk factors for stroke.',
#   0),
#  (269,
#   10,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Factors associated with major bleeding events: insights from the ROCKET AF trial (rivaroxaban once-daily oral direct factor Xa inhibition compared with vitamin K antagonism for prevention of stroke and embolism trial in atrial fibrillation).',
#   1),
#  (269,
#   11,
#   'What medication were compared in the ROCKET AF Trial?',
#   'In Rivaroxaban Once Daily Oral Direct Factor Xa Inhibitor Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET AF) trial, rivaroxaban was noninferior to dose-adjusted warfarin in preventing stroke or systemic embolism among patients with nonvalvular atrial fibrillation at moderate to high stroke risk.',
#   0),
#  (269,
#   12,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Different clinical trials have shown the benefits of new oral anticoagulants over warfarin, but patients included in the ROCKET-AF trial were found to be at a higher risk of AF-related complications.',
#   0),
#  (269,
#   13,
#   'What medication were compared in the ROCKET AF Trial?',
#   'The ROCKET AF trial demonstrated the noninferiority of rivaroxaban compared with warfarin for the prevention of stroke and systemic embolism, with a similar rate of major bleeding and a substantial reduction in intracranial hemorrhage.',
#   1),
#  (269,
#   14,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Rivaroxaban for stroke prevention in atrial fibrillation: a critical review of the ROCKET AF trial.',
#   0),
#  (269,
#   15,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Outcomes after cardioversion and atrial fibrillation ablation in patients treated with rivaroxaban and warfarin in the ROCKET AF trial.',
#   0),
#  (269,
#   16,
#   'What medication were compared in the ROCKET AF Trial?',
#   'The overall analysis of the rivaroxaban versus warfarin in Japanese patients with atrial fibrillation (J-ROCKET AF) trial revealed that rivaroxaban was not inferior to warfarin with respect to the primary safety outcome.',
#   0),
#  (269,
#   17,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Medical costs in the US of clinical events associated with oral anticoagulant (OAC) use compared to warfarin among non-valvular atrial fibrillation patients ≥75 and <75 years of age, based on the ARISTOTLE, RE-LY, and ROCKET-AF trials.',
#   0),
#  (269,
#   18,
#   'What medication were compared in the ROCKET AF Trial?',
#   'In patients at risk of stroke due to atrial fibrillation, rivaroxaban was noninferior compared to warfarin in preventing stroke/systemic embolism in the Rivaroxaban Once Daily Oral Direct Factor Xa Inhibition Compared with Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET-AF) trial and was associated with a similar risk of major bleeding; the incidence of intracranial hemorrhage was 33% lower with rivaroxaban',
#   0),
#  (269,
#   19,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Outcomes of discontinuing rivaroxaban compared with warfarin in patients with nonvalvular atrial fibrillation: analysis from the ROCKET AF trial (Rivaroxaban Once-Daily, Oral, Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation)',
#   1),
#  (269,
#   20,
#   'What medication were compared in the ROCKET AF Trial?',
#   'The Phase III ROCKET AF (Rivaroxaban Once-Daily Oral Direct Factor Xa Inhibition Compared with Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation) trial showed that rivaroxaban, an oral, direct Factor Xa inhibitor, was noninferior to warfarin for the reduction of stroke or systemic embolism in patients with AF',
#   0),
#  (269,
#   21,
#   'What medication were compared in the ROCKET AF Trial?',
#   'In Rivaroxaban Once Daily Oral Direct Factor Xa Inhibitor Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET AF) trial, rivaroxaban was noninferior to dose-adjusted warfarin in preventing stroke or systemic embolism among patients with nonvalvular atrial fibrillation at moderate to high stroke risk',
#   0),
#  (269,
#   22,
#   'What medication were compared in the ROCKET AF Trial?',
#   'We investigated clinical characteristics and outcomes of patients with significant valvular disease (SVD) in the Rivaroxaban Once Daily Oral Direct Factor Xa Inhibition Compared with Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET AF) trial',
#   0),
#  (269,
#   23,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Efficacy and safety of rivaroxaban compared with warfarin among elderly patients with nonvalvular atrial fibrillation in the Rivaroxaban Once Daily, Oral, Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET AF)',
#   0),
#  (269,
#   24,
#   'What medication were compared in the ROCKET AF Trial?',
#   'The oral factor Xa inhibitor rivaroxaban was noninferior to warfarin in the Rivaroxaban Once Daily, Oral, Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET AF)',
#   0),
#  (269,
#   25,
#   'What medication were compared in the ROCKET AF Trial?',
#   'We studied the use and outcomes of digoxin in patients in the Rivaroxaban Once Daily Oral Direct Factor Xa Inhibition Compared with Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET AF)',
#   0),
#  (269,
#   26,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Outcomes of discontinuing rivaroxaban compared with warfarin in patients with nonvalvular atrial fibrillation: analysis from the ROCKET AF trial (Rivaroxaban Once-Daily, Oral, Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation).',
#   1),
#  (269,
#   27,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Relationship between time in therapeutic range and comparative treatment effect of rivaroxaban and warfarin: results from the ROCKET AF trial.',
#   0),
#  (269,
#   28,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Efficacy and safety of rivaroxaban compared with warfarin among elderly patients with nonvalvular atrial fibrillation in the Rivaroxaban Once Daily, Oral, Direct Factor Xa Inhibition Compared With Vitamin K Antagonism for Prevention of Stroke and Embolism Trial in Atrial Fibrillation (ROCKET AF).',
#   0),
#  (269,
#   29,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Outcomes of temporary interruption of rivaroxaban compared with warfarin in patients with nonvalvular atrial fibrillation: results from the rivaroxaban once daily, oral, direct factor Xa inhibition compared with vitamin K antagonism for prevention of stroke and embolism trial in atrial fibrillation (ROCKET AF).',
#   0),
#  (269,
#   30,
#   'What medication were compared in the ROCKET AF Trial?',
#   ' Health care providers should consider renal function, concomitant medication, polymorbidity and age prior to prescribing rivaroxaban.',
#   0),
#  (269,
#   31,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Care has to be taken when prescribing rivaroxaban to patients who are different from those included in the ROCKET AF trial.',
#   0),
#  (269,
#   32,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Health care providers should consider renal function, concomitant medication, polymorbidity and age prior to prescribing rivaroxaban.',
#   0),
#  (269,
#   33,
#   'What medication were compared in the ROCKET AF Trial?',
#   'Care has to be taken when prescribing rivaroxaban to patients who are different from those included in the ROCKET AF trial.',
#   0),
#  (269,
#   34,
#   'What medication were compared in the ROCKET AF Trial?',
#   'A separate trial, J-ROCKET AF, compared the safety of a Japan-specific rivaroxaban dose with warfarin administered according to Japanese guidelines in Japanese patients with AF.J-ROCKET AF was a prospective, randomized, double-blind, phase III trial.',
#   0),
#  (269,
#   35,
#   'What medication were compared in the ROCKET AF Trial?',
#   'A separate trial, J-ROCKET AF, compared the safety of a Japan-specific rivaroxaban dose with warfarin administered according to Japanese guidelines in Japanese patients with AF.',
#   0),
#  (269,
#   36,
#   'What medication were compared in the ROCKET AF Trial?',
#   'J-ROCKET AF was a prospective, randomized, double-blind, phase III trial.',
#   0),
#  (956,
#   0,
#   'List programs suitable for pharmacophore modelling',
#   'Pharmacophore models based on thermolysin binding modes and activity profiles were generated using the LigandScout program',
#   0),
#  (956,
#   1,
#   'List programs suitable for pharmacophore modelling',
#   'In this study, pharmacophore hypotheses based on known inhibitors were generated using common feature pharmacophore generation protocol available in Discovery Studio program',
#   0),
#  (956,
#   2,
#   'List programs suitable for pharmacophore modelling',
#   ' A pharmacophore-based screening was then carried out using the program Catalyst',
#   0),
#  (956,
#   3,
#   'List programs suitable for pharmacophore modelling',
#   'The PharmaGist employed algorithm to identify the best pharmacophores by computing multiple flexible alignments between the input ligands.',
#   0),
#  (956,
#   4,
#   'List programs suitable for pharmacophore modelling',
#   'The multiple alignments are generated by combining alignments pair-wise between one of the gliptin input ligands, which acts as pivot and the other gliptin as ligand.',
#   0),
#  (956,
#   5,
#   'List programs suitable for pharmacophore modelling',
#   'The resulting multiple alignments reveal spatial arrangements of consensus features shared by different subsets of input ligands.',
#   0),
#  (956,
#   6,
#   'List programs suitable for pharmacophore modelling',
#   'The best pharmacophore model has been derived using both pair-wise and multiple alignment methods, which have been weighted in Pharmacophore Generation process',
#   0),
#  (956,
#   7,
#   'List programs suitable for pharmacophore modelling',
#   'Pharmacophore models of c-Met kinase inhibitors have been developed based on 22 diverse compounds by using HypoGen algorithm implemented in Discovery studio program package.',
#   0),
#  (956,
#   8,
#   'List programs suitable for pharmacophore modelling',
#   'chemical feature based pharmacophore models of MMP-1, MMP-8 and MMP-13 inhibitors have been developed with the aid of HypoGen module within Catalyst program package',
#   0),
#  (956,
#   9,
#   'List programs suitable for pharmacophore modelling',
#   'Genetic Algorithm Similarity Program (GASP) was used to derive a 3D pharmacophore model which was used in effective alignment of data set.',
#   1),
#  (956,
#   10,
#   'List programs suitable for pharmacophore modelling',
#   'Active site complimenting structure-based pharmacophore models were developed using Discovery Studio 2.5 program and validated using a dataset of known HDAC8 inhibitors.',
#   0),
#  (956,
#   11,
#   'List programs suitable for pharmacophore modelling',
#   ' pharmacophore model has been generated from the training set by means of the MOE (molecular operating environment) program.',
#   1),
#  (956,
#   12,
#   'List programs suitable for pharmacophore modelling',
#   'A training set of 20 compounds with known experimental activity was used to generate pharmacophore hypotheses using 3D QSAR Pharmacophore Generation module available in Discovery studio.',
#   0),
#  (956,
#   13,
#   'List programs suitable for pharmacophore modelling',
#   'Pharmacophore model was developed for the first time, on a training data set of 22 CCR3 antagonists, using CATALYST HypoRefine program.',
#   0),
#  (956,
#   14,
#   'List programs suitable for pharmacophore modelling',
#   'The CatalystHipHop approach was used to generate a pharmacophore model for cyclooxygenase-2 (COX-2) inhibitors based on a training set of 15 active inhibitors (1â15).',
#   1),
#  (956,
#   15,
#   'List programs suitable for pharmacophore modelling',
#   ' Molecular modeling study, including fitting to a 3D-pharmacophore model of the designed molecules (10a-g), with HCV NS3 protease hypothesis using catalyst program was fulfilled.',
#   1),
#  (956,
#   16,
#   'List programs suitable for pharmacophore modelling',
#   'pharmacophore model (Hypo1) with a well prediction capacity for CysLT(1) antagonists was developed using Catalyst/HypoGen program.',
#   0),
#  (956,
#   17,
#   'List programs suitable for pharmacophore modelling',
#   'Three pharmacophore models of opioid agonists were generated by the Catalyst/HypoGen program',
#   0),
#  (956,
#   18,
#   'List programs suitable for pharmacophore modelling',
#   'The superposition of the ligands was performed with the tool Pharmacophore Elucidation (MOE-package',
#   0),
#  (956,
#   19,
#   'List programs suitable for pharmacophore modelling',
#   'Known PDE-5 inhibitors were used to construct a three dimensional quantitative structure-activity relationship (3D QSAR) model by HypoGen program.',
#   0),
#  (956,
#   20,
#   'List programs suitable for pharmacophore modelling',
#   'pharmacophore models were generated for AT1 and ET(A) receptors based on highly selective AT1 and ET(A) antagonists using the program Catalyst/HipHop',
#   0),
#  (956,
#   21,
#   'List programs suitable for pharmacophore modelling',
#   ' In this study, chemical feature based pharmacophore models of inhibitors of 5-LOX have been developed with the aid of HipHop and HypoGen modules within Catalyst program package',
#   1),
#  (956,
#   22,
#   'List programs suitable for pharmacophore modelling',
#   'A data set consisting of 24 inhibitors was selected on the basis of the information content of the structures and activity data as required by the Catalyst/HypoGen program.',
#   0),
#  (1193,
#   0,
#   'What is the effect of thapsigargin treatment?',
#   ' the sarcoplasmic/endoplasmic Ca(2+)-ATPase (SERCA) inhibitor thapsigargin',
#   1),
#  (1193,
#   1,
#   'What is the effect of thapsigargin treatment?',
#   'Treatment of endoplasmic stress inducers, thapsigargin',
#   1),
#  (1193,
#   2,
#   'What is the effect of thapsigargin treatment?',
#   'the two unrelated reversible autophagy inhibitors 3-methyladenine (3MA) and thapsigargin (TG) both blocked cargo sequestration completely.',
#   0),
#  (1193,
#   3,
#   'What is the effect of thapsigargin treatment?',
#   'pretreatment with the endoplasmic reticulum Ca(2+) pump inhibitor thapsigargin (TG)',
#   1),
#  (1193,
#   4,
#   'What is the effect of thapsigargin treatment?',
#   ' pharmacological ER stress agents (thapsigargin and tunicamycin).',
#   0),
#  (1193,
#   5,
#   'What is the effect of thapsigargin treatment?',
#   ' thapsigargin-induced calcium depletion of sarcoplasmic reticular stores',
#   0),
#  (1193,
#   6,
#   'What is the effect of thapsigargin treatment?',
#   'Addition of thapsigargin (Tg), that induces store-depletion and activates TRPC1-mediated Ca(2+) entry, potentiated the Cl(-) current, which was inhibited by the addition of a non-specific TRPC channel blocker SKF96365 or removal of external Ca(2+).',
#   0),
#  (1193,
#   7,
#   'What is the effect of thapsigargin treatment?',
#   'we demonstrate that thapsigargin (TG) and tunicamycin (TM), two ERS inducers',
#   0),
#  (1193,
#   8,
#   'What is the effect of thapsigargin treatment?',
#   'hapsigargin, a sarco/endoplasmic reticulum Ca(2+)-ATPase (SERCA) Ca(2+) pump inhibitor',
#   1),
#  (1193,
#   9,
#   'What is the effect of thapsigargin treatment?',
#   'Thapsigargin-induced ER stress',
#   1),
#  (1193,
#   10,
#   'What is the effect of thapsigargin treatment?',
#   'SERCA2a inhibitor (thapsigargin)',
#   0),
#  (1193,
#   11,
#   'What is the effect of thapsigargin treatment?',
#   'he ER stressors, thapsigargin',
#   0),
#  (445,
#   0,
#   'Is there any relationship between histone ubiquitylation and splicing?',
#   'histone H2B-specific deubiquitinase and demonstrate that H2B deubiquitination by USP49 is required for efficient cotranscriptional splicing of a large set of exons.',
#   1),
#  (445,
#   1,
#   'Is there any relationship between histone ubiquitylation and splicing?',
#   'H2B monoubiquitylation (H2BK123ub1) marks introns in Saccharomyces cerevisiae',
#   1),
#  (445,
#   2,
#   'Is there any relationship between histone ubiquitylation and splicing?',
#   'H2B ubiquitination by facilitating splicing',
#   1),
#  (445,
#   3,
#   'Is there any relationship between histone ubiquitylation and splicing?',
#   'pre-mRNA splicing plays a critical role in histone H2B ubiquitination',
#   1),
#  (445,
#   4,
#   'Is there any relationship between histone ubiquitylation and splicing?',
#   'unanticipated functional link between histone H2B ubiquitination and pre-mRNA splicing',
#   1),
#  (2566,
#   0,
#   'What is the role of tankyrases in response to Double Strand Breaks (DSBs)?',
#   'Tankyrases Promote Homologous Recombination and Check Point Activation in Response to DSBs.',
#   1),
#  (2566,
#   1,
#   'What is the role of tankyrases in response to Double Strand Breaks (DSBs)?',
#   'Tankyrases Promote Homologous Recombination and Check Point Activation in Response to DSBs.',
#   1),
#  (307,
#   0,
#   'What family do mDia proteins belong in?',
#   'mDia proteins are members of the formin family of actin nucleating proteins that polymerize linear actin filaments.',
#   1),
#  (307,
#   1,
#   'What family do mDia proteins belong in?',
#   'mDia1, a linear actin nucleator of the Formin family',
#   1),
#  (307,
#   2,
#   'What family do mDia proteins belong in?',
#   'the mammalian Diaphanous members of the formin family of proteins (mDia) are two key players in the formation of filopodia and neurites.',
#   1),
#  (307,
#   3,
#   'What family do mDia proteins belong in?',
#   'mDia proteins are mammalian homologues of Drosophila diaphanous and belong to the formin family proteins that catalyze actin nucleation and polymerization.',
#   1),
#  (307,
#   4,
#   'What family do mDia proteins belong in?',
#   ' The mDia family of formins',
#   1),
#  (307,
#   5,
#   'What family do mDia proteins belong in?',
#   'interacts with the formin protein mDia1 (DIAPH1).',
#   0),
#  (307,
#   6,
#   'What family do mDia proteins belong in?',
#   'Formin-family proteins, in the active state, form actin-based structures such as stress fibres.',
#   0),
#  (307,
#   7,
#   'What family do mDia proteins belong in?',
#   'Their activation mechanisms, however, are largely unknown except that mDia and its closely related formins can be activated by direct binding of the small GTPase Rho or Cdc42.',
#   0),
#  (307,
#   8,
#   'What family do mDia proteins belong in?',
#   'Mouse Diaphanous-related formins (mDias) are members of the formin protein family that nucleate actin polymerization and subsequently promote filamentous actin (F-actin) elongation by monomer addition to fast-growing barbed ends.',
#   0),
#  (307,
#   9,
#   'What family do mDia proteins belong in?',
#   'Diaphanous related formins (DRFs) are part of the formin protein family that control morphogenesis, embryonic differentiation, cytokinesis, and cell polarity.',
#   0),
#  (307,
#   10,
#   'What family do mDia proteins belong in?',
#   'Diaphanous related formins (DRFs) are cytoskeleton remodeling proteins that mediate specific upstream GTPase signals to regulate cellular processes such as cytokinesis, cell polarity, and organelle motility.',
#   0),
#  (1494,
#   0,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'multifunctional 39 kDa Escherichia coli Ada protein (O6-methylguanine-DNA methyltransferase) (EC 2.1.1.63), product of the ada gene',
#   0),
#  (1494,
#   1,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'The Ada protein accepts stoichiometrically the alkyl group from O6-alkylguanine in DNA at the Cys-321 residue and from alkyl phosphotriester at the Cys-69 residue.',
#   1),
#  (1494,
#   2,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'This protein functions in DNA repair by direct dealkylation of mutagenic O6-alkylguanine.',
#   0),
#  (1494,
#   3,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'The protein methylated at Cys-69 becomes a transcriptional activator of the genes in the ada regulon, including its own.',
#   1),
#  (1494,
#   4,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'O6-Alkylguanine DNA-alkyltransferase (ATase) repairs toxic, mutagenic and carcinogenic O6-alkylguanine (O6-alkG) lesions in DNA',
#   0),
#  (1494,
#   5,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'O6-Methylguanine is removed from DNA via the transfer of the methyl group to a cysteine acceptor site present in the DNA repair protein O6-alkylguanine-DNA alkyltransferase.',
#   0),
#  (1494,
#   6,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'DNA repair by O6-alkylguanine-DNA alkyltransferases plays a major role in removing lesions responsible for GC-->AT transitions induced by CCNU, influencing their ultimate distribution with respect to sequence context.',
#   0),
#  (1494,
#   7,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'alkyltransferase (ATase)',
#   0),
#  (1494,
#   8,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'the ada ATase induced by exposure to low doses of a methylating agent.',
#   0),
#  (1494,
#   9,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'The Escherichia coli Ada and Ogt DNA methyltransferases (MTases) are known to transfer simple alkyl groups from O6-alkylguanine and O4-alkylthymine, directly restoring these alkylated DNA lesions to guanine and thymine.',
#   0),
#  (1494,
#   10,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'During exponential growth, the spontaneous rate of G:C to A:T transitions and G:C to C:G transversions was elevated about fourfold in ada ogt double mutant versus wild-type E. coli.',
#   0),
#  (1494,
#   11,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'compared with the wild type, stationary populations of the MTase-deficient E. coli (under lactose selection) displayed increased G:C to A:T and A:T to G:C transitions (10- and 3-fold, respectively) and increased G:C to C:G, A:T to C:G, and A:T to T:A transversions (10-, 2.5-, and 1.7-fold, respectively).',
#   1),
#  (1494,
#   12,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'ATases are able to repair O6-alkylguanine (O6-AlkG) and O4-alkylthymine (O4-AlkT)',
#   0),
#  (1494,
#   13,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'The inducible resistance to alkylation mutagenesis and killing in Escherichia coli (the adaptive response) is controlled by the ada gene.',
#   0),
#  (1494,
#   14,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'The Ada protein acts both as a positive regulator of the response and as a DNA repair enzyme, correcting premutagenic O6-alkylguanine in DNA by suicidal transfer of the alkyl group to one of its own cysteine residues.',
#   1),
#  (1494,
#   15,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'Forward mutations induced by 1-(2-chloroethyl)-3-cyclohexyl-1-nitrosourea (CCNU) in the lacl gene of Escherichia coli were recovered from bacteria proficient (Ogt+ Ada+) and deficient (Ogt- Ada-) in O6-alkylguanine-DNA alkyltransferase activity.',
#   0),
#  (1494,
#   16,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'Spontaneous mutagenesis in O6-alkylguanine-DNA alkyltransferase-proficient and -deficient (ada ogt mutants) Escherichia coli was studied in two ways: in bacteria growing in nonselective liquid medium and in bacteria resting on selective agar plates.',
#   0),
#  (1494,
#   17,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'We now show by Southern analysis that the mutation involves a gross deletion covering at least the ogt and fnr genes and that no O6-alkylguanine-DNA-alkyltransferase activity is present in cell-free extracts of an ada::Tn10 derivative of these bacteria.',
#   0),
#  (1494,
#   18,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'O6-Alkylguanine DNA-alkyltransferase (ATase) repairs toxic, mutagenic and carcinogenic O6-alkylguanine (O6-alkG) lesions in DNA by a highly conserved reaction involving the stoichiometric transfer of the alkyl group to the active centre cysteine residue of the ATase protein.',
#   1),
#  (1494,
#   19,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'Although the human O6-alkylguanine-DNA alkyltransferase (AGT) is very sensitive to inactivation by O6-benzylguanine (BG) or 2,4-diamino-6-benzyloxy-5-nitrosopyrimidine (5-nitroso-BP), the equivalent protein formed by the carboxyl terminal domain of the product of the Escherichia coli ada gene (Ada-C) is unaffected by these inhibitors.',
#   0),
#  (1494,
#   20,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'A mutant of Bacillus subtilis defective in the constitutive activity of O6-alkylguanine-DNA alkyltransferase was isolated from a strain (ada-1) deficient in the adaptive response to DNA alkylation.',
#   0),
#  (1494,
#   21,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'Mutations in the Ada O6-alkylguanine-DNA alkyltransferase conferring sensitivity to inactivation by O6-benzylguanine and 2,4-diamino-6-benzyloxy-5-nitrosopyrimidine.',
#   0),
#  (1494,
#   22,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'The protein O 6-alkylguanine-DNA alkyltransferase(alkyltransferase) is involved in the repair of O 6-alkylguanine and O 4-alkylthymine in DNA and plays an important role in most organisms in attenuating the cytotoxic and mutagenic effects of certain classes of alkylating agents.',
#   0),
#  (1494,
#   23,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'O6-Alkylguanine-DNA alkyltransferase (EC 2.1.1.63) repairs O6-alkylguanine lesions in DNA.',
#   0),
#  (1494,
#   24,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'Spontaneous mutagenesis in O6-alkylguanine-DNA alkyltransferase-proficient and -deficient (ada ogt mutants) Escherichia coli was studied in two ways: in bacteria growing in nonselective liquid medium and in bacteria resting on selective agar plates',
#   0),
#  (1494,
#   25,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'The protein O 6-alkylguanine-DNA alkyltransferase(alkyltransferase) is involved in the repair of O 6-alkylguanine and O 4-alkylthymine in DNA and plays an important role in most organisms in attenuating the cytotoxic and mutagenic effects of certain classes of alkylating agents',
#   0),
#  (1494,
#   26,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'In summary, this paper presents for the first time evidence that DNA repair by O6-alkylguanine-DNA alkyltransferases plays a major role in removing lesions responsible for GC-->AT transitions induced by CCNU, influencing their ultimate distribution with respect to sequence context.',
#   0),
#  (1494,
#   27,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'Forward mutations induced by 1-(2-chloroethyl)-3-cyclohexyl-1-nitrosourea (CCNU) in the lacl gene of Escherichia coli were recovered from bacteria proficient (Ogt+ Ada+) and deficient (Ogt- Ada-) in O6-alkylguanine-DNA alkyltransferase activity',
#   0),
#  (1494,
#   28,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'Repair of O6-benzylguanine by the Escherichia coli Ada and Ogt and the human O6-alkylguanine-DNA alkyltransferases.',
#   0),
#  (1494,
#   29,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'O6-Alkylguanine DNA-alkyltransferase (ATase) repairs toxic, mutagenic and carcinogenic O6-alkylguanine (O6-alkG) lesions in DNA by a highly conserved reaction involving the stoichiometric transfer of the alkyl group to the active centre cysteine residue of the ATase protein',
#   0),
#  (1494,
#   30,
#   'What is the role of the Ada O6-alkylguanine alkyltransferase in bacteria?',
#   'O6-Alkylguanine-DNA alkyltransferase (EC 2.1.1.63) repairs O6-alkylguanine lesions in DNA',
#   0),
#  (1916,
#   0,
#   'What is Bexsero?',
#   'A capsular group B meningococcal vaccine - 4CMenB (Bexsero) - has recently been licensed in the European Union, Canada and Australia.',
#   1),
#  (1916,
#   1,
#   'What is Bexsero?',
#   'The 4-component meningococcal serogroup B vaccine 4CMenB (Bexsero) is the first vaccine against this serogroup and has been approved by licensing authorities in Europe, Canada and Australia.',
#   1),
#  (1916,
#   2,
#   'What is Bexsero?',
#   "Implementation of meningococcal B vaccination (Bexsero®) in France: Physicians' perceptions and experiences of a few months after marketing approval",
#   0),
#  (1916,
#   3,
#   'What is Bexsero?',
#   'In December 2013, the French public health authorities recommended the use of Bexsero® (meningococcus B vaccine) in areas with endemic risk and for patients at risk for invasive meningococcal B disease.',
#   0),
#  (1916,
#   4,
#   'What is Bexsero?',
#   'Bexsero, a novel vaccine against meningococcus',
#   0),
#  (1916,
#   5,
#   'What is Bexsero?',
#   'Meningococcus B is the most prevalent Neisseria meningitidis serogroup isolated in Hungary.',
#   0),
#  (1916,
#   6,
#   'What is Bexsero?',
#   'Bexsero is one of the vaccines developed against it, which has been available in Hungary since the summer of 2014.',
#   0),
#  (1916,
#   7,
#   'What is Bexsero?',
#   'Vaccinating Italian infants with a new multicomponent vaccine (Bexsero®) against meningococcal B disease: A cost-effectiveness analysis.',
#   0),
#  (1916,
#   8,
#   'What is Bexsero?',
#   'The European Medicines Agency has approved a multicomponent serogroup B meningococcal vaccine (Bexsero®) for use in individuals of 2 months of age and older.',
#   0),
#  (1916,
#   9,
#   'What is Bexsero?',
#   'Our results suggest that vaccinating infants in Italy with Bexsero® has the ability to significantly reduce meningococcal disease and, if the probable underestimation of disease incidence is considered, routine vaccination is advisable.',
#   0),
#  (1916,
#   10,
#   'What is Bexsero?',
#   'Since the antigens selected for Bexsero® are also harbored by meningococci belonging to other serogroups there may be the potential for Bexsero® to offer a certain level of protection against non-B serogroups.',
#   0),
#  (1916,
#   11,
#   'What is Bexsero?',
#   '[Bexsero, a novel vaccine against meningococcus].',
#   0),
#  (1916,
#   12,
#   'What is Bexsero?',
#   'The new available vaccines are Bexsero® and Trumenba®.',
#   0),
#  (1916,
#   13,
#   'What is Bexsero?',
#   'Surface-expressed protein antigens such as factor H-binding protein (fHbp), Neisserial adhesin A (NadA), Neisserial heparin-binding antigen (NHBA) and Porin protein A (PorA); all express sequence variability that can affect their function as protective immunogens when used in meningococcal serogroup B vaccines like the recently-approved 4CMenB (Bexsero(®)).',
#   0),
#  (1916,
#   14,
#   'What is Bexsero?',
#   'Proteinaceous meningococcal B vaccines are under development, and the most advanced, Bexsero, is currently being evaluated by the European Medicines Agency.',
#   0),
#  (1916,
#   15,
#   'What is Bexsero?',
#   'Among them, the Reverse Vaccinology approach was successfully applied to the development of an innovative vaccine against Neisseria meningitidis serogroup B, now available on the market with the commercial name BEXSERO® (Novartis Vaccines).',
#   0),
#  (1916,
#   16,
#   'What is Bexsero?',
#   'Recently, a vaccine, 4CMenB (Bexsero(®)), containing three recombinant proteins, and outer membrane vesicles (OMV) derived from a serogroup B meningococcal strain (MenB) has been licensed in Europe and Australia and is indicated for persons aged 2 mo or older.',
#   0),
#  (1916,
#   17,
#   'What is Bexsero?',
#   'Multicomponent meningococcal serogroup B vaccine (4CMenB; Bexsero(®)) is a unique vaccine containing four main immunogenic components: three recombinant proteins combined with outer membrane vesicles derived from meningococcal NZ98/254 strain',
#   0),
#  (1916,
#   18,
#   'What is Bexsero?',
#   'Recently, a universal serogroup B meningococcal vaccine, Bexsero(®), was licensed in Europe, Australia and United States, following several clinical studies demonstrating its immunogenicity and safety',
#   0),
#  (1916,
#   19,
#   'What is Bexsero?',
#   'Like any drug, Bexsero(®) and Trumemba(®) will require close observation to assess their impact on meningococcal epidemiology.',
#   0),
#  (1916,
#   20,
#   'What is Bexsero?',
#   '<CopyrightInformation>Copyright © 2015 Elsevier Masson SAS',
#   0),
#  (1916,
#   21,
#   'What is Bexsero?',
#   'Bexsero, a new vaccine against Neisseria meningitidis serogroup B (MenB), is composed of 3 main recombinant proteins and an outer membrane vesicle component',
#   1),
#  (1916,
#   22,
#   'What is Bexsero?',
#   'The meningococcal 4CMenB vaccine (Bexsero; Novartis) contains four antigens that can elicit serum bactericidal activity, one of which is factor H (FH)-binding protein (FHbp)',
#   0),
#  (1916,
#   23,
#   'What is Bexsero?',
#   'In December 2013 Bexsero® became available in Germany for vaccination against serogroup B meningococci (MenB)',
#   0),
#  (1916,
#   24,
#   'What is Bexsero?',
#   'Bexsero® is based on surface protein antigens expressed by about 80% of circulating serogroup B meningococci in Germany',
#   0),
#  (1916,
#   25,
#   'What is Bexsero?',
#   'Re-evaluating cost effectiveness of universal meningitis vaccination (Bexsero) in England: modelling study.',
#   0),
#  (1916,
#   26,
#   'What is Bexsero?',
#   'Bexsero: a multicomponent vaccine for prevention of meningococcal disease.',
#   0),
#  (1916,
#   27,
#   'What is Bexsero?',
#   'OBJECTIVE: To use mathematical and economic models to predict the epidemiological and economic impact of vaccination with Bexsero, designed to protect against group B meningococcal disease, to help inform vaccine policy in the United Kingdom.DESIGN: Modelling study.SETTING: England.POPULATION: People aged 0-99.INTERVENTIONS: Incremental impact of introductory vaccine strategies simulated with a transmission dynamic model of meningococcal infection and vaccination including potential herd effects.',
#   0),
#  (1916,
#   28,
#   'What is Bexsero?',
#   'Preventing secondary cases of invasive meningococcal capsular group B (MenB) disease using a recently-licensed, multi-component, protein-based vaccine (Bexsero(�)).',
#   0),
#  (1916,
#   29,
#   'What is Bexsero?',
#   'Modelled evaluation of multi-component meningococcal vaccine (Bexsero®) for the prevention of invasive meningococcal disease in infants and adolescents in the UK.',
#   0),
#  (1916,
#   30,
#   'What is Bexsero?',
#   'BACKGROUND: 4CMenB (Bexsero), a vaccine developed against invasive meningococcal disease caused by capsular group B strains (MenB), was recently licensed for use by the European Medicines Agency.',
#   0),
#  (1916,
#   31,
#   'What is Bexsero?',
#   'Bexsero is the first meningococcal B vaccine to be approved in the European Union.',
#   0),
#  (1916,
#   32,
#   'What is Bexsero?',
#   'Quantification by LC-MS(E) of outer membrane vesicle proteins of the Bexsero® vaccine.',
#   0),
#  (1916,
#   33,
#   'What is Bexsero?',
#   'We previously demonstrated the immunogenicity and tolerability of the serogroup B meningococcal vaccine, 4CMenB (Bexsero), in 11-17 y-olds randomized to receive 1, 2, or 3 doses at 1, 2, or 6 mo intervals.',
#   0),
#  (1916,
#   34,
#   'What is Bexsero?',
#   'This policy statement provides recommendations for the prevention of serogroup B meningococcal disease through the use of 2 newly licensed serogroup B meningococcal vaccines: MenB-FHbp (Trumenba; Wyeth Pharmaceuticals, a subsidiary of Pfizer, Philadelphia, PA) and MenB-4C (Bexsero; Novartis Vaccines, Siena, Italy).',
#   0),
#  (1916,
#   35,
#   'What is Bexsero?',
#   'An outbreak of Neisseria meningitidis serotype B infection occurred at a small residential university; public health announced an organizational vaccination program with the 4-component Meningococcal B (4CMenB) vaccine (Bexsero(TM), Novartis/GlaxoSmithKline Inc.) several days later.',
#   0),
#  (1916,
#   36,
#   'What is Bexsero?',
#   'Bexsero, a new vaccine against serogroup B meningococcal disease (MenB), was licensed in Europe in January 2013.',
#   1),
#  (1916,
#   37,
#   'What is Bexsero?',
#   'Recently approved in the EU, US, Australia, and Canada, 4CMenB (Bexsero(®), GSK Vaccines) is a multi-component meningococcal B (MenB) vaccine containing 3 surface exposed recombinant proteins (fHbp, NadA, and NHBA) and New Zealand strain outer membrane vesicles (NZ OMV) containing PorA 1.4.',
#   0),
#  (1916,
#   38,
#   'What is Bexsero?',
#   'In Germany, Bexsero is recommended for persons at increased risk of invasive meningococcal disease, but not for universal childhood vaccination.',
#   0),
#  (1916,
#   39,
#   'What is Bexsero?',
#   'To support decision making we adapted the independently developed model for England to the German setting to predict the potential health impact and cost-effectiveness of universal vaccination with Bexsero(®) against MenB disease.',
#   0),
#  (1916,
#   40,
#   'What is Bexsero?',
#   'This has resulted in a multicomponent, recombinant, meningococcal serogroup B vaccine: 4CMenB (Bexsero(®), Novartis Vaccines & Diagnostics, NC, USA), containing four main immunogenic components: two recombinant fusion proteins (Neisseria heparin-binding antigen-GNA1030 and factor H-binding protein-GNA2091); recombinant Neisserial adhesion A; and detergent-treated outer membrane vesicles derived from the meningococcal NZ98/254 strain, where porin A 1.4 is the major immunodominant antigen.',
#   0),
#  (1916,
#   41,
#   'What is Bexsero?',
#   'BACKGROUND: 4CMenB (Bexsero), a vaccine developed against invasive meningococcal disease caused by capsular group B strains (MenB), was recently licensed for use by the European Medicines Agency.',
#   0),
#  (1916,
#   42,
#   'What is Bexsero?',
#   'In January 2015, FDA licensed a second MenB vaccine (MenB-4C [Bexsero, Novartis Vaccines]) as a 2-dose series.',
#   0),
#  (1916,
#   43,
#   'What is Bexsero?',
#   'Bexsero, a new vaccine against Neisseria meningitidis serogroup B (MenB), is composed of 3 main recombinant proteins and an outer membrane vesicle component.',
#   0),
#  (1916,
#   44,
#   'What is Bexsero?',
#   'Preventing secondary cases of invasive meningococcal capsular group B (MenB) disease using a recently-licensed, multi-component, protein-based vaccine (Bexsero(®)).',
#   0),
#  (1916,
#   45,
#   'What is Bexsero?',
#   '[Bexsero, a novel vaccine against meningococcus].',
#   0),
#  (1916,
#   46,
#   'What is Bexsero?',
#   "Modelling the cost-effectiveness of catch-up 'MenB' (Bexsero) vaccination in England.",
#   0),
#  (1916,
#   47,
#   'What is Bexsero?',
#   'Re-evaluating cost effectiveness of universal meningitis vaccination (Bexsero) in England: modelling study.',
#   0),
#  (1916,
#   48,
#   'What is Bexsero?',
#   'The novel vaccine Bexsero (previously 4CMenB) has been developed and proven safe and immunogenic in clinical trials.',
#   0),
#  (1916,
#   49,
#   'What is Bexsero?',
#   'Multicomponent meningococcal serogroup B vaccine (4CMenB; Bexsero(®)): a review of its use in primary and booster vaccination.',
#   0),
#  (1916,
#   50,
#   'What is Bexsero?',
#   'Bexsero, the recently licensed multicomponent vaccine against serogroup B Neisseria meningitidis (MenB).',
#   1),
#  (1916,
#   51,
#   'What is Bexsero?',
#   'Recommendation for anti-meningococcal vaccination among these workers has been recently updated upon the licensure in Europe of Bexsero® vaccine.',
#   0),
#  (1916,
#   52,
#   'What is Bexsero?',
#   'Clinical recommendations for the use of Bexsero have been published in several countries.',
#   0),
#  (471,
#   0,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   ' flavivirus NS5 harbors a methyltransferase (MTase) in its N-terminal ≈ 265 residues and an RNA-dependent RNA polymerase (RdRP) within the C-terminal part.',
#   0),
#  (471,
#   1,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'One of the major interests and challenges in NS5 is to understand the interplay between RdRP and MTase as a unique natural fusion protein in viral genome replication and cap formation.',
#   0),
#  (471,
#   2,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'Here, we report the first crystal structure of the full-length flavivirus NS5 from Japanese encephalitis virus.',
#   1),
#  (471,
#   3,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   '(DENV) nonstructural protein 5 (NS5) is composed of two globular domains separated by a 10-residue linker.',
#   0),
#  (471,
#   4,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   "The N-terminal domain participates in the synthesis of a mRNA cap 1 structure ((7Me)GpppA(2'OMe)) at the 5' end of the viral genome and possesses guanylyltransferase, guanine-N7-methyltransferase, and nucleoside-2'O-methyltransferase activities.",
#   0),
#  (471,
#   5,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'The C-terminal domain is an RNA-dependent RNA polymerase responsible for viral RNA synthesis.',
#   0),
#  (471,
#   6,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'Although crystal structures of the two isolated domains have been obtained, there are no structural data for full-length NS5.',
#   1),
#  (471,
#   7,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'It is also unclear whether the two NS5 domains interact with each other to form a stable structure in which the relative orientation of the two domains is fixed.',
#   1),
#  (471,
#   8,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'To investigate the structure and dynamics of DENV type 3 NS5 in solution, we conducted small-angle X-ray scattering experiments with the full-length protein.',
#   1),
#  (471,
#   9,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'NS5 was found to be monomeric and well-folded under the conditions tested.',
#   0),
#  (471,
#   10,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'West Nile virus (WNV) NS5 protein contains a methyltransferase (MTase) domain involved in RNA capping and an RNA-dependent RNA polymerase (RdRp) domain essential for virus replication.',
#   0),
#  (471,
#   11,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'Crystal structures of individual WNV MTase and RdRp domains have been solved; however, the structure of full-length NS5 has not been determined.',
#   1),
#  (471,
#   12,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'To gain more insight into the structure of NS5 and interactions between the MTase and RdRp domains, we generated a panel of seven monoclonal antibodies (mAbs) to the NS5 protein of WNV (Kunjin strain) and mapped their binding sites using a series of truncated NS5 proteins and synthetic peptides.',
#   0),
#  (471,
#   13,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'Binding sites of four mAbs (5D4, 4B6, 5C11 and 6A10) were mapped to residues 354-389 in the fingers subdomain of the RdRp.',
#   0),
#  (471,
#   14,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'This is consistent with the ability of these mAbs to inhibit RdRp activity in vitro and suggests that this region represents a potential target for RdRp inhibitors.',
#   0),
#  (471,
#   15,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
#   'Using a series of synthetic peptides, we also identified a linear epitope (bound by mAb 5H1) that mapped to a 13 aa stretch surrounding residues 47 and 49 in the MTase domain, a region predicted to interact with the palm subdomain of the RdRp.',
#   0),
#  (471,
#   16,
#   'Is there a crystal structure of the full-length of the flaviviridae NS5(Methyltransferase - RNA depended RNA Polymerase) ?',
# ...
#   0),
#  (1376,
#   16,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Alcohol-induced alterations in hepatic microtubule dynamics can be explained by impaired histone deacetylase 6 function',
#   0),
#  (1376,
#   17,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Addition of trichostatin A (TSA), an HDAC6 inhibitor, induced microtubule acetylation to the same extent as in ethanol-treated cells (approximately threefold).',
#   0),
#  (1376,
#   18,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Interestingly, HDAC6 from ethanol-treated cells was able to bind and deacetylate exogenous tubulin to the same extent as control, suggesting that ethanol-induced tubulin modifications prevented HDAC6 binding to endogenous microtubules.',
#   0),
#  (1376,
#   19,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'We propose that lower HDAC6 levels combined with decreased microtubule binding lead to increased tubulin acetylation in ethanol-treated cells.',
#   0),
#  (1376,
#   20,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'The results also showed that both pan-HDAC and class-I-specific inhibitor treatment resulted in increased acetylation of histones, but only pan-HDAC inhibitor treatment resulted in increased tubulin acetylation, which is in agreement with their activity towards the HDAC6 isoform.',
#   0),
#  (1376,
#   21,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Nicotinamide but not 3-aminobenzamide, an inhibitor for poly(ADP)ribose polymerase, enhanced tubulin acetylation and resistance to axonal degeneration in cultured cerebellar granule cells from wild-type (WT) mice, suggesting that mammalian Sir2-related protein (SIRT) 2, a nicotinamide adenine dinucleotide (NAD)--dependent tubulin deacetylase, could modulate resistance to axonal degeneration.',
#   0),
#  (1376,
#   22,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Moreover, SIRT2 overexpression abrogated microtubule hyperacetylation and resistance to axonal degeneration in these cells.',
#   0),
#  (1376,
#   23,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Conversely, SIRT2 knockdown by using a lentiviral vector expressing small interfering RNA, enhanced microtubule acetylation and resistance to axonal degeneration in WT granule cells.',
#   0),
#  (1376,
#   24,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Taken together, these results suggest that SIRT2-mediated tubulin deacetylation is involved in both microtubule hyperacetylation and resistance to axonal degeneration in Wld(S) granule cells.',
#   0),
#  (1376,
#   25,
#   'Which are the enzymes involved in the control of tubulin acetylation?',
#   'Compared to control cultures, higher levels of acetylated tubulin were found in neurons treated with tubacin',
#   1),
#  (648,
#   0,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'The dimer formed by the ATF-2 and c-Jun transcription factors is one of the main components of the human interferon-beta enhanceosome.',
#   0),
#  (648,
#   1,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'The induction of IFN transcription resulted from the activation of the components of the IFN-beta enhanceosome, i.e.',
#   0),
#  (648,
#   2,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'IFN regulatory factor (IRF) 3, nuclear factor (NF)-kappaB, activating transcription factor (ATF)-2 and c-Jun.',
#   0),
#  (648,
#   3,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional activation of the interferon-beta (IFN-beta) gene requires assembly of an enhanceosome containing the transcription factors ATF-2/c-Jun, IRF-3/IRF-7, NF-kappaB and HMGI(Y).',
#   0),
#  (648,
#   4,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'These factors cooperatively bind a composite DNA site and activate expression of the IFN-beta gene.',
#   0),
#  (648,
#   5,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Here we report that within the IFN-beta enhanceosome the ATF-2-c-jun heterodimer binds in a specific orientation, which is required for assembly of a complex between ATF-2-c-jun and interferon regulatory factor 3 (IRF-3).',
#   0),
#  (648,
#   6,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   ' Here, we identified a small molecule that induces the assembly of the interferon-beta (IFN-beta) enhanceosome by stimulating all the enhancer-binding activator proteins: ATF2/c-JUN, IRF3, and p50/p65 of NF-kappaB.',
#   0),
#  (648,
#   7,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional activation of the virus inducible enhancer of the human interferon-beta (IFN-beta) gene in response to virus infection requires the assembly of an enhanceosome, consisting of the transcriptional activators NF-kappaB, ATF-2/c-Jun, IRFs and the architectural protein of the mammalian high mobility group I(Y) [HMG I(Y)].',
#   1),
#  (648,
#   8,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Here, we demonstrate that the first step in enhanceosome assembly, i.e.',
#   0),
#  (648,
#   9,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'HMG I(Y)-dependent recruitment of NF-kappaB and ATF-2/c-Jun to the enhancer, is facilitated by discrete regions of HMG I and is mediated by allosteric changes induced in the DNA by HMG I(Y) and not by protein-protein interactions between HMG I(Y) and these proteins.',
#   0),
#  (648,
#   10,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'However, we show that completion of the enhanceosome assembly process requires protein-protein interactions between HMG I(Y) and the activators.',
#   0),
#  (648,
#   11,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional activation of the human interferon-beta (IFN-beta) gene by virus infection requires the assembly of a higher order nucleoprotein complex, the enhanceosome, which consists of the transcriptional activators NF-kappa B (p50/p65), ATF-2/c-jun, IRF-3 and IRF-7, architectural protein HMGI(Y), and the coactivators p300 and CBP.',
#   1),
#  (648,
#   12,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'The transcriptional coactivators CBP and P/CAF are required for activation of transcription from the IFN beta enhanceosome.',
#   0),
#  (648,
#   13,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'We show that CBP and P/CAF acetylate HMG I(Y), the essential architectural component required for enhanceosome assembly, at distinct lysine residues, causing distinct effects on transcription.',
#   0),
#  (648,
#   14,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'The transcriptional activity of an in vitro assembled human interferon-beta gene enhanceosome is highly synergistic.',
#   0),
#  (648,
#   15,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'This synergy requires five distinct transcriptional activator proteins (ATF2/c-JUN, interferon regulatory factor 1, and p50/p65 of NF-kappaB), the high mobility group protein HMG I(Y), and the correct alignment of protein-binding sites on the face of the DNA double helix.',
#   0),
#  (648,
#   16,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'In addition, we provide evidence that recruitment of the holoenzyme by the enhanceosome is due, at least in part, to interactions between the enhanceosome and the transcriptional coactivator CREB, cAMP responsive element binding protein (CBP).',
#   0),
#  (648,
#   17,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional activation of the IFN beta gene in response to virus infection requires the assembly of an enhanceosome, consisting of the transcriptional activators NF-kappa B, IRF1, ATF2/c-Jun, and the architectural protein HMG I(Y).',
#   1),
#  (648,
#   18,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional synergy requires recruitment of the CBP/p300 coactivator to the enhanceosome, via a new activating surface assembled from the novel p65 domain and the activation domains of all of the activators.',
#   0),
#  (648,
#   19,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'A functional interferon-beta gene enhanceosome was assembled in vitro using the purified recombinant transcriptional activator proteins ATF2/c-JUN, IRF1, and p50/p65 of NF-kappa B. Maximal levels of transcriptional synergy between these activators required the specific interactions with the architectural protein HMG I(Y) and the correct helical phasing of the binding sites of these proteins on the DNA helix.',
#   0),
#  (648,
#   20,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'We present evidence that transcriptional activation of the human interferon-beta (IFN beta) gene requires the assembly of a higher order transcription enhancer complex (enhanceosome).',
#   0),
#  (648,
#   21,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'This multicomponent complex includes at least three distinct transcription factors and the high mobility group protein HMG I(Y).',
#   0),
#  (648,
#   22,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Thus, HMG I(Y) plays an essential role in the assembly and function of the IFN beta gene enhanceosome.',
#   0),
#  (648,
#   23,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional activation of the interferon-beta (IFN-beta) gene requires assembly of an enhanceosome containing the transcription factors ATF-2/c-Jun, IRF-3/IRF-7, NF-kappaB and HMGI(Y).',
#   0),
#  (648,
#   24,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'A functional interferon-beta gene enhanceosome was assembled in vitro using the purified recombinant transcriptional activator proteins ATF2/c-JUN, IRF1, and p50/p65 of NF-kappa B',
#   0),
#  (648,
#   25,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional activation of the human interferon-beta (IFN-beta) gene by virus infection requires the assembly of a higher order nucleoprotein complex, the enhanceosome, which consists of the transcriptional activators NF-kappa B (p50/p65), ATF-2/c-jun, IRF-3 and IRF-7, architectural protein HMGI(Y), and the coactivators p300 and CBP',
#   1),
#  (648,
#   26,
#   'Which transcription factors (TFs) participate in the formation of the interferon-beta (IFN-b) enhanceosome?',
#   'Transcriptional activation of the IFN beta gene in response to virus infection requires the assembly of an enhanceosome, consisting of the transcriptional activators NF-kappa B, IRF1, ATF2/c-Jun, and the architectural protein HMG I(Y)',
#   1),
#  (380,
#   0,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'The strongest associations were for mood swings (OR 20.9, 95%CI 16.2-27.0), memory loss/lack of concentration (OR 19.6, 95% CI 15.5-24.8), night sweats (OR 9.9, 95% CI 6.5-15.2), general fatigue (OR 9.6, 95% CI 8.3-11.1) and sexual dysfunction (OR 4.6, 95%CI 3.2-6.6).',
#   0),
#  (380,
#   1,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'The symptoms include incapacitating fatigue, musculoskeletel and joint pains, headaches, neuropsychiatric disorders, affect changes, confusion, visual problems, changes of gait, loss of memory, lymphadenopathies, respiratory impairment, impotence, and urinary tract morphological and functional alterations.',
#   1),
#  (380,
#   2,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'In early 1992, U.S. troops returning from the Gulf War began reporting a variety of nonspecific symptoms such as fatigue, skin rash, headache, muscle and joint pain, and loss of memory.',
#   1),
#  (380,
#   3,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'These reports marked the beginning of what was to be identified as the Gulf War Syndrome (GWS).',
#   1),
#  (380,
#   4,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'We report on a 29-year-old man who suffered from dysmnesia, disturbance of orientation, cognitive impairment, and double vision.',
#   0),
#  (380,
#   5,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'His history revealed several front-line operations in 1990 and 1991 during the Gulf War.',
#   1),
#  (380,
#   6,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'Neuropsychological tests disclosed severe cognitive impairment especially concerning memory.',
#   0),
#  (380,
#   7,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'A cluster of common health problems included: skin rash, cough, depression, unintentional weight loss, insomnia, and memory problems.',
#   1),
#  (380,
#   8,
#   'What memory problems are reported in the " Gulf war syndrome"?',
#   'Syndromes 1 ("impaired cognition," characterized by problems with attention, memory, and reasoning, as well as insomnia, depression, daytime sleepiness, and headaches), 2 ("confusion-ataxia," characterized by problems with thinking, disorientation, balance disturbances, vertigo, and impotence), and 3 ("arthro-myo-neuropathy," characterized by joint and muscle pains, muscle fatigue, difficulty lifting, and extremity paresthesias) represented strongly clustered symptoms; whereas, syndromes 4 ("phobia-apraxia"), 5 ("fever-adenopathy"), and 6 ("weakness-incontinence") involved weaker clustering and mostly overlapped syndromes 2 and 3.',
#   0),
#  (3161,
#   0,
#   'List targets of classical analgesics.',
#   'Patient phenotypes in pharmacological pain treatment varies between individuals, which could be partly assigned to their genotypes regarding the targets of classical analgesics (OPRM1, PTGS2)',
#   1),
#  (3161,
#   1,
#   'List targets of classical analgesics.',
#   'Morphine is the current gold standard analgesic acting at MOP receptors but produces a range of variably troublesome side-effects, in particular tolerance.',
#   1),
#  (3560,
#   0,
#   'What is the cyberknife used for?',
#   'Stereotactic radiosurgery using CyberKnife® seems to be an efficient and safe therapeutic option for malignant melanomas affecting the choroid and ciliary body.',
#   1),
#  (3560,
#   1,
#   'What is the cyberknife used for?',
#   'Stereotactic radiosurgery (SRS) has emerged as a principal alternative to microresection for small- and medium-sized CSHs.',
#   1),
#  (3560,
#   2,
#   'What is the cyberknife used for?',
#   'CyberKnife® is a robotic stereotactic radiotherapy system.',
#   1),
#  ...]

# %% [markdown]
# # Task 2 (5 marks): Cosine similarity
#
# Use the files `training.csv`, `dev_test.csv`, and `test.csv` provided by us in the file `data.zip` (so that any possible errors that you may have introduced in task 1 do not propagate to this task and following tasks).
#
# Implement a simple text summariser that is based on the cosine similarity between the question and the text. Use the following function signature.
#
# ```{python}
# def cosine_summariser(csvfile, questionids, n=5):
#    """Return the IDs of the n sentences that have the highest cosine similarity
#     with the question. The input questionids is a list of question ids. The
#     output is a list of lists of sentence ids
#     >>> cosine_summariser('test.csv', [3, 11], 3)
#     [[3, 1, 4], [12, 4, 13]]"""
#
# ```
#
# To obtain the text vectors, use sklearn's tf.idf libraries this way:
#
# * Use all the defaults from the TfidfVectorizer instance, except for `stop_words="english"` and `max_features=10000`. The latter option will restrict the vocabulary size to 10,000. This will speed up the computations and reduce the memory footprint in the subsequent tasks.
# * Use the `fit` method on the text of `training.csv`. In your documentation, please explain and justify what decision choices you made to select the correct text: would you use the question text only, the sentence text, or both?
#
# Evaluate the summariser by reporting the mean F1 score on each of the three CSV files `training.csv`, `devtest.csv`, and `test.csv`, for $n=5$. To calculate the mean F1 score, do this:
#
# 1. For each question ID in the file, calculate the F1 score by comparing the result of your cosine summariser and the given labels. Feel free to use sklearn's functions to compute the F1 score, or implement your own version of the F1 scoring function if you prefer.
# 2. Calculate the mean of the F1 scores calculated in step 1.
#
# Find the value of $n$ that returns the highest mean F1 score on the dev_test data.
#
# The breakdown of marks is as follows:
#
# * **1 mark** if the code generates the tf.idf vectors correctly. The explanations that justify the decisions made are reasonable. In particular, explain and justify what information you used to fit tf.idf.
# * **1 mark** if the code calculates cosine similarity correctly.
# * **1 mark** if the code returns the IDs of the $n$ sentences that have the highest cosine similarity with the question.
# * **1 mark** if the notebook reports the F1 scores of the dev_test file and identifies the value of $n$ that gives the highest score on the dev_test file.
# * **1 mark** for good coding and documentation in this task. In particular, comment on the reason why you think the value of $n$ that gives highest F1 has that value.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(input='contents', max_features=10000, stop_words = "english")
train_tfidf = tfidf.fit_transform([r[2] for r in training_set])

# %%
def cosine_summariser(csvfile, questionids, n=5):
   """Return the IDs of the n sentences that have the highest cosine similarity
    with the question. The input questionids is a list of question ids. The 
    output is a list of lists of sentence ids
    >>> cosine_summariser('test.csv', [3, 11], 3)
    [[3, 1, 4], [12, 4, 13]]"""

# %% [markdown]
# # Task 3 (5 marks): Simple NN
#
# Use the files `training.csv`, `dev_test.csv`, and `test.csv` provided by us.
#
# Implement a simple TensorFlow-Keras neural model that has the following sequence of layers:
#
# 1. An input layer that will accept the tf.idf of the sentence text (we will ignore the question text in this task). Use the TfidfVectorizer instance that you have fitted in task 2.
# 2. A hidden layer and a relu activation function. You need to determine the size of the hidden layer.
# 3. An output layer with one cell. The output layer will classify the input text (binary classification).
#
# Train the model with the training data and use the dev_test set to determine a good size of the hidden layer.
#
# With the model that you have trained, and implement a summariser that returns the $n$ sentences with highest predicted score. Use the following function signature:
#
# ```{python}
# def nn_summariser(csvfile, questionids, n=5):
#    """Return the IDs of the n sentences that have the highest predicted score. The input questionids is a list of question ids. The
#     output is a list of lists of sentence ids
#     >>> cosine_summariser('test.csv', [3, 11], 3)
#     [[2, 1, 3], [7, 14, 10]]"""
#
# ```
#
# Report the final results using the test set. Remember: use the test set to report the final results of the best system only.
#
# Based on your experiments, comment on whether this system is better than the system developed in task 2. To make this task less time-consuming, focus only on $n=5$.
#
# The breakdown of marks is as follows:
#
# * **1 mark** if the NN model has the correct layers, the correct activation functions, and the correct loss function.
# * **1 mark** if the code passes the tf.idf information of the text to the model correctly.
# * **1 mark** if the code returns the IDs of the $n$ sentences that have the highest prediction score in the given question.
# * **1 mark** if the notebook reports the F1 scores of the test sets and comments on the results.
# * **1 mark** for good coding and documentation in this task. In particular, the code and results must include evidence that shows your choice of best size of the hidden layer. The explanations must be clear and concise. To make this task less time-consuming, use $n=5$.

# %%
# Write your code and answers here. Feel free to add more code and markdown cells.
from tensorflow.keras import models, layers

# %%
simple_nn = models.Sequential()
simple_nn.add(layers.Dense(363, activation='sigmoid', input_shape=(len(tfidf.get_feature_names()),)))
simple_nn.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 363)               1732236
#
# =================================================================
# Total params: 1,732,236
# Trainable params: 1,732,236
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Task 4 (5 marks): Recurrent NN
#
# Use the files `training.csv`, `dev_test.csv`, and `test.csv` provided by us.
#
# Implement a more complex neural network that is composed of the following layers:
#
# * An embedding layer that generates embedding vectors of the sentence text with 35 dimensions.
# * A LSTM layer. You need to determine the size of this LSTM layer, and the text length limit (if needed).
# * The final output layer with one cell for binary classification, as in task 3.
#
# Train the model with the training data, use the dev_test set to determine a good size of the LSTM layer and an appropriate length limit (if needed), and report the final results using the test set. Again, remember to use the test set only after you have determined the optimal parameters of the LSTM layer.
#
# Based on your experiments, comment on whether this system is better than the systems developed in the previous tasks.
#
# The breakdown of marks is as follows:
#
# * **1 mark** if the NN model has the correct layers, the correct activation functions, and the correct loss function.
# * **1 mark** if the code passes the sentence text to the model correctly. The documentation needs to explain what decisions had to be made to process long sentences. In particular, did you need to truncate the input text, and how did you determine the length limit?
# * **1 mark** if the code returns the IDs of the *n* sentences that have the highest prediction score in the given question.
# * **1 mark** if the notebook reports the F1 scores of the test sets and comments on the results.
# * **1 mark** for good coding and documentation in this task. In particular, the code and results must include evidence that shows your choice of best size of the LSTM layer. The explanations must be clear and concise. To make this task less time-consuming, use $n=5$.

# %%
# Write your code and answers here. Feel free to add more code and markdown cells.

# %% [markdown]
# # Submission of results
#
# Your submission should consist of this Jupyter notebook with all your code and explanations inserted into the notebook as text cells. **The notebook should contain the output of the runs. All code should run. Code with syntax errors or code without output will not be assessed.**
#
# **Do not submit multiple files. If you feel you need to submit multiple files, please contact Diego.Molla-Aliod@mq.edu.au first.**
#
# Examine the text cells of this notebook so that you can have an idea of how to format text for good visual impact. You can also read this useful [guide to the MarkDown notation](https://daringfireball.net/projects/markdown/syntax),  which explains the format of the text cells.
#
# Each task specifies a number of marks. The final mark of the assignment is the sum of all the marks of each individual task.
#
# By submitting this assignment you are acknowledging that this is your own work. Any submissions that break the code of academic honesty will be penalised as per [the academic integrity policy](https://policies.mq.edu.au/document/view.php?id=3).
#
# Late submissions **will not be accepted** without an approved [Special Consideration](http://from.mq.edu.au/MT0X0E0FUrrU200rm0JB0U0) request.  Assessments submitted after the due date will receive a mark of **zero**.
